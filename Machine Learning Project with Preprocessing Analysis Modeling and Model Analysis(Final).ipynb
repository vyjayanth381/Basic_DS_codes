# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('F://Final.csv')

# %%
df
# Out:
#            Audi     1968  Diesel  20.38                 A3   3491000.0  5  \
# 0          Audi     1968  Diesel  20.38                 A3   3669000.0  5
# 1          Audi     1395  Petrol   19.2                 A3   3310000.0  5
# 2          Audi     1395  Petrol   19.2                 A3   3510000.0  5
# 3          Audi     1968  Diesel  15.73                 Q3   3653000.0  5
# 4          Audi     1968  Diesel  15.73                 Q3   3968000.0  5
# 5          Audi     1395  Petrol   16.9                 Q3   3473000.0  5
# 6          Audi     1968  Diesel   16.9                 Q3   4076000.0  5
# 7          Audi     1968  Diesel  18.25                 A4   4337000.0  5
# 8          Audi     1395  Petrol  17.84                 A4   4147000.0  5
# 9          Audi     1395  Petrol  17.84                 A4   4505000.0  5
# 10         Audi     1968  Diesel  16.55                 A4   4694000.0  5
# 11         Audi     1798  Petrol   16.6       A3 Cabriolet   4486219.0  4
# ...

# %%
df=df.drop('Unnamed: 8',axis=1)
df.head(3)
# Out:
#    Audi  1968  Diesel  20.38  A3  3491000.0  5  Automatic  \
# 0  Audi  1968  Diesel  20.38  A3  3669000.0  5  Automatic
# 1  Audi  1395  Petrol   19.2  A3  3310000.0  5  Automatic
# 2  Audi  1395  Petrol   19.2  A3  3510000.0  5  Automatic
#
#     35 TDI Premium Plus Unnamed: 10
# 0     35 TDI Technology         NaN
# 1  35 TFSI Premium Plus         NaN
# 2    35 TFSI Technology         NaN

# %%
df.keys()
# Out:
# Index(['Audi', '1968', 'Diesel', '20.38', 'A3', '3491000.0', '5', 'Automatic',
#        '35 TDI Premium Plus', 'Unnamed: 10'],
#       dtype='object')

# %%
df.columns=['Brand','CC','EngineType','Mileage','Model','Price','SeatCapacity','Transmission','Variant1','Variant2']

# %%
df.head(3)
# Out:
#   Brand    CC EngineType Mileage Model      Price  SeatCapacity Transmission  \
# 0  Audi  1968     Diesel   20.38    A3  3669000.0             5    Automatic
# 1  Audi  1395     Petrol    19.2    A3  3310000.0             5    Automatic
# 2  Audi  1395     Petrol    19.2    A3  3510000.0             5    Automatic
#
#                Variant1 Variant2
# 0     35 TDI Technology      NaN
# 1  35 TFSI Premium Plus      NaN
# 2    35 TFSI Technology      NaN

# %%
df.isnull().sum()
# Out:
# Brand             0
# CC                0
# EngineType        0
# Mileage           0
# Model             0
# Price             0
# SeatCapacity      0
# Transmission      0
# Variant1        198
# Variant2        302
# dtype: int64

# %%
round(100*(df.isnull().sum()/len(df.index)),2)
# Out:
# Brand            0.0
# CC               0.0
# EngineType       0.0
# Mileage          0.0
# Model            0.0
# Price            0.0
# SeatCapacity     0.0
# Transmission     0.0
# Variant1        39.6
# Variant2        60.4
# dtype: float64

# %%
#removing cc in CC columns:
cc=[]
for i in df['CC']:
    i=str(i).replace('cc','')
    cc.append(i)

# %%
df['CC']=cc

# %%
df
# Out:
#           Brand     CC EngineType Mileage              Model       Price  \
# 0          Audi   1968     Diesel   20.38                 A3   3669000.0
# 1          Audi   1395     Petrol    19.2                 A3   3310000.0
# 2          Audi   1395     Petrol    19.2                 A3   3510000.0
# 3          Audi   1968     Diesel   15.73                 Q3   3653000.0
# 4          Audi   1968     Diesel   15.73                 Q3   3968000.0
# 5          Audi   1395     Petrol    16.9                 Q3   3473000.0
# 6          Audi   1968     Diesel    16.9                 Q3   4076000.0
# 7          Audi   1968     Diesel   18.25                 A4   4337000.0
# 8          Audi   1395     Petrol   17.84                 A4   4147000.0
# 9          Audi   1395     Petrol   17.84                 A4   4505000.0
# 10         Audi   1968     Diesel   16.55                 A4   4694000.0
# 11         Audi   1798     Petrol    16.6       A3 Cabriolet   4486219.0
# ...

# %%
df.EngineType.value_counts()
# Out:
# Petrol     277
# Diesel     191
#  Petrol     11
# CNG         10
#  Diesel      9
# Hybrid       2
# Name: EngineType, dtype: int64

# %%
typ=[]
for i in df['EngineType']:
    i=str(i).replace(' ','')
    typ.append(i)

# %%
df['EngineType']=typ

# %%
df.EngineType.value_counts()
# Out:
# Petrol    288
# Diesel    200
# CNG        10
# Hybrid      2
# Name: EngineType, dtype: int64

# %%
at=[]
for i in df['Transmission']:
    i=str(i).replace(' ','')
    at.append(i)

df['Transmission']=at
df.Transmission.value_counts()

#or

#df['Transmission']=df['Transmission'].apply(lambda X: X.strip())
# Out:
# Manual       327
# Automatic    173
# Name: Transmission, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
# Brand           500 non-null object
# CC              500 non-null int32
# EngineType      500 non-null object
# Mileage         500 non-null object
# Model           500 non-null object
# Price           500 non-null float64
# SeatCapacity    500 non-null int64
# Transmission    500 non-null object
# Variant1        302 non-null object
# Variant2        198 non-null object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 37.2+ KB

# %%
df['CC']=df.CC.astype(int)
df['Mileage']=df.Mileage.astype(float)
#df['Transmission']=df.Transmission.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-df464ce6d652> in <module>
#       1 df['CC']=df.CC.astype(int)
# ----> 2 df['Mileage']=df.Mileage.astype(float)
#       3 #df['Transmission']=df.Transmission.astype(int)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5689             # else, only a single dtype is given
#    5690             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 5691                                          **kwargs)
#    5692             return self._constructor(new_data).__finalize__(self)
#    5693
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     529
#     530     def astype(self, dtype, **kwargs):
# ...

# %%
# In mileaage 'Nissan Sunny' is coming to remove that we need type the following code:

df['Mileage']=pd.to_numeric(df['Mileage'],errors='coerce')

# %%
df['Mileage']=df.Mileage.astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
# Brand           500 non-null object
# CC              500 non-null int32
# EngineType      500 non-null object
# Mileage         499 non-null float64
# Model           500 non-null object
# Price           500 non-null float64
# SeatCapacity    500 non-null int64
# Transmission    500 non-null object
# Variant1        302 non-null object
# Variant2        198 non-null object
# dtypes: float64(2), int32(1), int64(1), object(6)
# memory usage: 37.2+ KB

# %%
x=df['Mileage'].mean()
# Out:
# 19.672985971943937

# %%
df["Mileage"].fillna("19.67", inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 10 columns):
# Brand           500 non-null object
# CC              500 non-null int32
# EngineType      500 non-null object
# Mileage         500 non-null object
# Model           500 non-null object
# Price           500 non-null float64
# SeatCapacity    500 non-null int64
# Transmission    500 non-null object
# Variant1        302 non-null object
# Variant2        198 non-null object
# dtypes: float64(1), int32(1), int64(1), object(7)
# memory usage: 37.2+ KB

# %%
df['Variant']=df['Variant1'].combine_first(df['Variant2'])
# we can also use combine_firts use fillna

# %%
# Out:
#                         Variant1  \
# 0              35 TDI Technology
# 1           35 TFSI Premium Plus
# 2             35 TFSI Technology
# 3             30 TDI Premium FWD
# 4    35 TDI quattro Premium Plus
# 5                30 TFSI Premium
# 6         2.0 TDI Design Edition
# 7            35 TDI Premium Plus
# 8           30 TFSI Premium Plus
# 9        30 TFSI Technology Pack
# 10        35 TDI Technology Pack
# 11                       40 TFSI
# 12           35 TDI Premium Plus
# 13             35 TDI Technology
# 14          45 TFSI Premium Plus
# 15            45 TFSI Technology
# 16                     Sportback
# 17                 35 TDI Matrix
# 18                35 TFSI Matrix
# 19                       45 TFSI
# 20                       2.0 TDI
# 21                       60 TFSI
# 22                        50 TDI
# 23                        60 TDI
# 24                           W12
# 25                   50 TDI Plus
# 26                           NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
# Brand           500 non-null object
# CC              500 non-null int32
# EngineType      500 non-null object
# Mileage         500 non-null object
# Model           500 non-null object
# Price           500 non-null float64
# SeatCapacity    500 non-null int64
# Transmission    500 non-null object
# Variant1        302 non-null object
# Variant2        198 non-null object
# Variant         500 non-null object
# dtypes: float64(1), int32(1), int64(1), object(8)
# memory usage: 41.1+ KB

# %%
df=df.drop('Variant1',axis=1)
df=df.drop('Variant2',axis=1)

# %%
df.head()
# Out:
#   Brand    CC EngineType Mileage Model      Price  SeatCapacity Transmission  \
# 0  Audi  1968     Diesel   20.38    A3  3669000.0             5    Automatic
# 1  Audi  1395     Petrol    19.2    A3  3310000.0             5    Automatic
# 2  Audi  1395     Petrol    19.2    A3  3510000.0             5    Automatic
# 3  Audi  1968     Diesel   15.73    Q3  3653000.0             5       Manual
# 4  Audi  1968     Diesel   15.73    Q3  3968000.0             5    Automatic
#
#                        Variant
# 0            35 TDI Technology
# 1         35 TFSI Premium Plus
# 2           35 TFSI Technology
# 3           30 TDI Premium FWD
# 4  35 TDI quattro Premium Plus

# %%
# or else we can use  df['Variant']=df['Variant1'].fillna(df['Variant2'].str.strip())----> 
#bcoz, here in variant2 there is more space.. to remove that we use strip

vv=[]
for i in df['Variant']:
    i=str(i).replace('  ','')
    vv.append(i)

# %%
df['Variant']=vv

# %%
df.Variant
# Out:
# 0              35TDITechnology
# 1            35TFSIPremiumPlus
# 2             35TFSITechnology
# 3              30TDIPremiumFWD
# 4      35TDIquattroPremiumPlus
# 5                30TFSIPremium
# 6          2.0TDIDesignEdition
# 7             35TDIPremiumPlus
# 8            30TFSIPremiumPlus
# 9         30TFSITechnologyPack
# 10         35TDITechnologyPack
# 11                      40TFSI
# 12            35TDIPremiumPlus
# 13             35TDITechnology
# 14           45TFSIPremiumPlus
# 15            45TFSITechnology
# 16                   Sportback
# 17                 35TDIMatrix
# 18                35TFSIMatrix
# 19                      45TFSI
# 20                      2.0TDI
# 21                      60TFSI
# 22                       50TDI
# 23                       60TDI
# 24                         W12
# 25                   50TDIPlus
# 26                      D-Lite
# 27                     D-Lite+
# 28                        Era+
# 29                      Magna+
# ...

# %%
# Out:
# 0              35TDITechnology
# 1            35TFSIPremiumPlus
# 2             35TFSITechnology
# 3              30TDIPremiumFWD
# 4      35TDIquattroPremiumPlus
# 5                30TFSIPremium
# 6          2.0TDIDesignEdition
# 7             35TDIPremiumPlus
# 8            30TFSIPremiumPlus
# 9         30TFSITechnologyPack
# 10         35TDITechnologyPack
# 11                      40TFSI
# 12            35TDIPremiumPlus
# 13             35TDITechnology
# 14           45TFSIPremiumPlus
# 15            45TFSITechnology
# 16                   Sportback
# 17                 35TDIMatrix
# 18                35TFSIMatrix
# 19                      45TFSI
# 20                      2.0TDI
# 21                      60TFSI
# 22                       50TDI
# 23                       60TDI
# 24                         W12
# 25                   50TDIPlus
# 26                      D-Lite
# 27                     D-Lite+
# 28                        Era+
# 29                      Magna+
# ...
