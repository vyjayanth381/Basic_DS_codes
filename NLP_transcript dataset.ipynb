# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
#plt.style.use('seaborn')
import nltk # natural language tool-kit
import re

# %%
data= pd.read_fwf('F://transcript.txt',header=None,names=['id','text','unknown'])   #fwf--> fixed with formatted lines

# %%
data.head()
# Out:
#           id                                               text unknown
# 0  33_1_0001  okay let's see i want to go to a thai restaura...     NaN
# 1  33_1_0002  <i> <like> <to> <eat> [uh] i like to eat at lu...     NaN
# 2  33_1_0003    i don't want to walk for more than five minutes     NaN
# 3  33_1_0004  tell me more about the [uh] na- nakapan [uh] r...     NaN
# 4  33_1_0005             i like to go to a hamburger restaurant     NaN

# %%
data.drop('unknown',inplace=True,axis=1)

# %%
data.head(3)
# Out:
#           id                                               text
# 0  33_1_0001  okay let's see i want to go to a thai restaura...
# 1  33_1_0002  <i> <like> <to> <eat> [uh] i like to eat at lu...
# 2  33_1_0003    i don't want to walk for more than five minutes

# %% [markdown]
# ### text cleaning:
# - lower case
# - remove numbers
# - remove spl characters
# - take root word (love,loving,loved in this 3 words root word is Love(ignoring present past future singular prural etc...))
#     - from this we need to do stemming and lemmatization

# %%
## Example

# %%
text= 'Innomatics Research Labs, Located in Nizampet X road, PIN: 500085'

# %%
#step-----1
pre_text= text.lower()
print(pre_text)
## step-----2---> special characters and NUmbers

#re.findall(r'\W',pre_text)
pre_text =  re.sub(r'[^a-z]',' ',pre_text)

pre_text
# Out:
# innomatics research labs, located in nizampet x road, pin: 500085
# 'innomatics research labs  located in nizampet x road  pin        '

# %%
ps= nltk.stem.PorterStemmer()   # stemmer
word= 'loving'
ps.stem(pre_text)
# Out:
# 'innomatics research labs  located in nizampet x road  pin        '

# %%
pre_text.strip().split(' ')
# Out:
# ['innomatics',
#  'research',
#  'labs',
#  '',
#  'located',
#  'in',
#  'nizampet',
#  'x',
#  'road',
#  '',
#  'pin']

# %%
#or 
from nltk import word_tokenize

# %%
words= word_tokenize(pre_text)
print(words)
# Out:
# ['innomatics', 'research', 'labs', 'located', 'in', 'nizampet', 'x', 'road', 'pin']

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Home
# [nltk_data]     PC\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
' '.join([ps.stem(word) for word in words]) ##
# Out:
# 'innomat research lab locat in nizampet x road pin'

# %%
data
# Out:
#              id                                               text
# 0     33_1_0001  okay let's see i want to go to a thai restaura...
# 1     33_1_0002  <i> <like> <to> <eat> [uh] i like to eat at lu...
# 2     33_1_0003    i don't want to walk for more than five minutes
# 3     33_1_0004  tell me more about the [uh] na- nakapan [uh] r...
# 4     33_1_0005             i like to go to a hamburger restaurant
# 5     33_1_0006                                  let's start again
# 6     33_1_0007  i like to get a hamburger at an american resta...
# 7     33_1_0008  i'd like to eat dinner . and i don't mind walk...
# 8     33_1_0009  i don't want to spend more than [uh] ten dolla...
# 9     33_1_0010  <(te)-ll> <me> <more> <about> <the> <two> <bar...
# 10    33_1_0011  tell me about everett and jones barbecue flint...
# 11    33_1_0012     where's the best place to get soup in berkeley
# 12    33_1_0013  where's the best place to get soup in berkeley...
# 13    33_1_0014               what types of food do you understand
# 14    33_1_0015  i want indian food and i have chuck's car so i...
# 15    33_1_0016  what about the indian cafe . can you give me i...
# 16    33_1_0017                             tell me about pasand's
# 17    33_1_0018                   [uh] tell me about moe's burgers
# 18    43_1_0001        a cheap restaurant near by that serves meat
# 19    43_1_0002                           like to eat pork or beef
# 20    43_1_0003                      bacon and eggs . or breakfast
# 21    43_1_0004               more information about addison annex
# 22    3A_1_0001  yeah i'd like to go out for some thai food [uh...
# 23    3A_1_0002                            [uh] how about six p__m
# 24    3A_1_0003                           make it walking distance
# 25    3A_1_0004              tell me about the thai barbecue place
# 26    3A_1_0005  yeah i'm looking for a vegetarian place that's...
# 27    3A_1_0006   [mm] i'll s- i'll spend a lot of money this time
# 28    3A_1_0007                             doesn't matter how far
# 29    3A_1_0008             tell me about the long life vegi house
# ...         ...                                                ...
# 8536  29_2_0034                                one hundred dollars
# 8537  29_2_0035                                          ten miles
# 8538  29_2_0036                                where is dwight way
# 8539  29_2_0037                     i want the service to be quick
# 8540  29_2_0038                                         start over
# 8541  29_2_0039                    i want to eat a very quick meal
# 8542  29_2_0040                                 it does not matter
# 8543  29_2_0041                                          right now
# 8544  29_2_0042                         i want an inexpensive meal
# 8545  29_2_0043                           it needs to be very fast
# 8546  29_2_0044                     what is the closest restaurant
# 8547  29_2_0045                                         one minute
# 8548  29_2_0046                how about two minutes [loud_breath]
# 8549  29_2_0047                   do have information on taco-bell
# 8550  29_2_0048  there is a restaurant right outside called foo...
# 8551  29_2_0049                                         start over
# 8552  29_2_0050                                          hamburger
# 8553  29_2_0051                                           tomorrow
# 8554  29_2_0052                                              lunch
# 8555  29_2_0053                                              lunch
# 8556  29_2_0054                                              close
# 8557  29_2_0055                                   what is the cost
# 8558  29_2_0056                            do they have milkshakes
# 8559  29_2_0057                                          ethiopian
# 8560  29_2_0058                                twenty minutes away
# 8561  29_2_0059                                             dinner
# 8562  29_2_0060                 is there a restaurant an hour away
# 8563  29_2_0061                   the distance i travel is an hour
# 8564  29_2_0062               do you have no ethiopian restaurants
# 8565  29_2_0063                  what californian food do you have
#
# [8566 rows x 2 columns]

# %%
# text process or text Normalization----> nothing but text cleaning

# %%
def textnormalization(text):
    #step-----1
    pre_text= text.lower()
    ## step-----2---> special characters and NUmbers
    pre_text =  re.sub(r'[^a-z ]','',pre_text)
    # step-3---> Tokenization
    words = word_tokenize(pre_text) # to get words
    # step-4---> stemming
    sent = ' '.join([ps.stem(word) for word in words])
    return sent

# %%
data['text_norm']= data['text'].apply(textnormalization)
data.head()
# Out:
#           id                                               text  \
# 0  33_1_0001  okay let's see i want to go to a thai restaura...
# 1  33_1_0002  <i> <like> <to> <eat> [uh] i like to eat at lu...
# 2  33_1_0003    i don't want to walk for more than five minutes
# 3  33_1_0004  tell me more about the [uh] na- nakapan [uh] r...
# 4  33_1_0005             i like to go to a hamburger restaurant
#
#                                            text_norm
# 0  okay let see i want to go to a thai restaur uh...
# 1  i like to eat uh i like to eat at lunch time s...
# 2       i dont want to walk for more than five minut
# 3  tell me more about the uh na nakapan uh restau...
# 4                  i like to go to a hamburg restaur

# %%
data.isnull().sum()
# Out:
# id           0
# text         0
# text_norm    0
# dtype: int64

# %%
# drop if any missing values

# %% [markdown]
# ### N-gram Data preperation:

# %%
from nltk import ngrams, bigrams, trigrams # natural language tool kit

# %%
#taking 1st sentence and analysis
sent1 = data['text_norm'][0]

# %%
tokens = word_tokenize(sent1)   # get words in a list
ndata=list(ngrams(tokens,2,   #2--> bigram, 3-> is trigram and we can choose any number 
           pad_left=True,   # this like table (ref:notes)
           pad_right=True,
           left_pad_symbol='<sos>',      #sos--> start of sentence
           right_pad_symbol='</sos>'))

# %%
pd.DataFrame(ndata).head()   # convert it into dataframe
# Out:
#        0     1
# 0  <sos>  okay
# 1   okay   let
# 2    let   see
# 3    see     i
# 4      i  want

# %%
def bigrams (sent,ng=2):
    try:
        tokens = word_tokenize(sent)#get words in a list
        return list(ngrams(tokens,n=ng,pad_left=True,
                          pad_right=True,
                          left_pad_symbol='<sos>',right_pad_symbol='</sos>'))
    except:
        pass #skip if any error occurs

# %%
corpus = list(data['text_norm'])
corpus
# Out:
# ['okay let see i want to go to a thai restaur uh with less than ten dollar per person',
#  'i like to eat uh i like to eat at lunch time so that would be eleven am to one pm',
#  'i dont want to walk for more than five minut',
#  'tell me more about the uh na nakapan uh restaur on martin luther king',
#  'i like to go to a hamburg restaur',
#  'let start again',
#  'i like to get a hamburg at an american restaur',
#  'id like to eat dinner and i dont mind walk uh for half an hour',
#  'i dont want to spend more than uh ten dollar for a hamburg',
#  'tell me more about the two barbecu restaur tell me more about the two barbecu restaur you list',
#  'tell me about everett and jone barbecu flint barbecu and the thai barbecu pleas',
#  'where the best place to get soup in berkeley',
#  'where the best place to get soup in berkeley for lunch for under ten dollar uh with a ten minut walk',
#  'what type of food do you understand',
#  'i want indian food and i have chuck car so i can drive in but i onli want to drive for ten minut and i onli want to pay five dollar',
#  'what about the indian cafe can you give me inform about that',
#  'tell me about pasand',
#  'uh tell me about moe burger',
#  'a cheap restaur near by that serv meat',
#  'like to eat pork or beef',
#  'bacon and egg or breakfast',
#  'more inform about addison annex',
#  'yeah id like to go out for some thai food uh not too expens',
#  'uh how about six pm',
#  'make it walk distanc',
#  'tell me about the thai barbecu place',
#  'yeah im look for a vegetarian place that open on wednesday',
#  'mm ill s ill spend a lot of money thi time',
#  'doesnt matter how far',
#  'tell me about the long life vegi hous',
#  'i would like to eat american food or mexican food',
#  'i would like to um eat lunch today',
#  'i would like to have lunch',
#  'um i dont want to spend a lot of money uh so someth fairli cheap would be good',
#  'i wan na eat someplac that close to icsi',
#  'i want to eat uh italian',
#  'um i i dont mind spend a lot of money but i i dont wan na i dont wan na go someplac cheap i guess middl rang would be',
#  'uh i dont mind uh have to drive someplac doesnt have to be close to icsi',
#  'i need to find a uh place to eat uh for next uh saturday',
#  'id like to eat uh italian food or or american food either one',
#  'uh i want the a restaur where i can get some lunch um tomorrow',
#  'id like to find someth that fairli cheap',
#  'um id like someth that uh within walk distanc of icsi',
#  'is there anyth cheaper than that',
#  'i want to find a inexpens place to eat dinner',
#  'i think i would like to eat some vegetarian food',
#  'i would also um in addit to vegetarian i would also like to tri to see if i can find some mexican food',
#  'i want to find some place that fairli close to icsi',
#  'can you give me some more inform on manuel',
#  'i want to find a realli nice place to eat lunch next wednesday',
#  'i want to eat either french food california food or italian food',
#  'i have a car so the distanc is not import',
#  'can you give me some more inform on skate',
#  'can you show me those the list of restaur again',
#  'id like to see some more inform on augusta',
#  'can i see the origin list again',
#  'pleas tell me more about fourth street grill',
#  'alacart addison annex amaru arinel pizza augusta',
#  'aycaramba berkeley thai hous bett ocean view blondi pizza blue nile',
#  'bombay cuisin brennan brick hut cafe britmari cactu taqueria',
#  'cafe fanni cafe marmara cafe pastor cafe vin cafe violeta',
#  'caff giovanni caff venezia cambodiana casadeeva casbah',
#  'chaam chezpaniss chezpaniss cafe christoph cafe claremont seafood',
#  'coffe renaiss continent garden daruma teashop elmwood pharmaci everett and jone barbecu',
#  'beep fat slice pizza fat appl flint barbecu fourth street grill gerti',
#  'gramma inn guerrero homemad cafe hongfu hongkong villa',
#  'intern hous cafe joshuya juan place juic bar collect kip',
#  'kirala la mediterrane laval lalim lococo restaur',
#  'lilli long life vegi hous maharani manuel mario la fiesta',
#  'lipsmack meal ticket metropol nadin omnivor orient food to go',
#  'panini pasand madra cuisin pepito mexican deli petrouchka picant taqueria',
#  'plearn thai cuisin rich potstick ristorant venezia sandwich agogo saul deli',
#  'shinshin siam cuisin skate soup kitchen heik spenger',
#  'stuf inn sujatha sushisho taiwan restaur thai barbecu',
#  'lipsmack the milvia the swallow top dog tsingtao vasiliki',
#  'vegi food vietnam villag viva taqueria westsid bakeri',
#  'won thai cuisin yorkshir fish and chip zachari chicago',
#  'id like to eat some chines food',
#  'i want to eat thi afternoon',
#  'i want to spend no more than seven dollar',
#  'i want to travel no more than three block',
#  'id like to eat some italian food',
#  'id like to eat monday afternoon',
#  'id like to spend no more than fifti dollar',
#  'uh id like to travel no more than twenti block',
#  'when is caff venezia open dure the day',
#  'id like to eat some mexican food today and id like to spend no more than forti dollar',
#  'loudbreath id like to eat mexican food today',
#  'id like to spend no more than one hundr dollar',
#  'lipsmack id like to go to a restaur that is not fast food',
#  'laughter loudbreath id like to',
#  'id like to travel no more than twenti minut',
#  'loudbreath where is uh cactu taqueria locat',
#  'pleas show the list',
#  'lipsmack i wa think about go out for some french food tonight',
#  'how about loudbreath twelv dollar a person',
#  'ill tri to get a car so it shouldnt matter loudbreath',
#  'loudbreath whi dont you make that up to sixteen dollar',
#  'loudbreath can i have more inform on um lipsmack metropol',
#  'can you tell me about asian food in berkeley',
#  'dinner ani night',
#  'im a student so it had best not be better than more more laughter best not be more than six dollar a person',
#  'lipsmack doesnt matter how far i wan na see everyth here',
#  'can you tell me more about orient food to go to go and um vietnam villag',
#  'where the most expens russian place in berkeley',
#  'loudbreath dinner is best',
#  'it can be anywher',
#  'lipsmack alacart addison annex amaru arinel pizza augusta',
#  'aycaramba berkeley thai hous bett ocean view blondi pizza blue nile',
#  'brennan brick hut cafe britmari cactu taqueria cafe fanni',
#  'cafe marmara cafe pastor cafe vin cafe violeta caff giovanni',
#  'caff venezia cambodiana casadeeva casbah chaam',
#  'chezpaniss chezpaniss cafe christoph cafe claremont seafood coffe renaiss',
#  'continent garden daruma teashop elmwood pharmaci everett and jone barbecu fat slice pizza',
#  'fat appl flint barbecu fourth street grill gerti gramma inn',
#  'guerrero homemad cafe hongfu hongkong villa intern hous cafe',
#  'joshuya juan place juic juic bar collect kip kirala',
#  'la mediterrane laval lalim lococo restaur lilli',
#  'long life vegi hous maharani manuel mario la fiesta meal ticket',
#  'metropol nadin omnivor orient food to go panini',
#  'pasand madra cuisin pepito mexican deli petrouchka picant taqueria',
#  'plearn thai cuisin rich potstick ristorant venezia sandwich agogo',
#  'saul deli shinshin siam cuisin skate soup kitchen heik',
#  'spenger stuf inn sujatha sushisho taiwan restaur',
#  'thai barbecu the milvia the swallow top dog tsingtao',
#  'vasiliki vegi food vietnam villag viva taqueria westsid bakeri',
#  'won thai cuisin yorkshir fish and chip beep zachari chicago yorkshir fish and chip',
#  'i want to eat lunch today',
#  'i want to eat dinner on sunday even',
#  'money is no object',
#  'sinc i have a car travel distanc is not import',
#  'i would like to eat some cuban food not to spend more than twenti five dollar',
#  'i would like to eat some russian food and not spend more than ten dollar',
#  'i would like to eat thi late afternoon',
#  'i would like not to travel more than a mile away from here',
#  'i would like to eat some russian food',
#  'tell me about',
#  'tell me someth about petrouchka',
#  'i would like to have some uh fish food for dinner and um im not realli sure what type of restaur it should be whether or',
#  'like to i would like to um eat tonight um at seven oclock pm approxim',
#  'uh someth in the medium rang let say about twenti twenti five dollar per person',
#  'oh um how far from icsi um lipsmack somewher either in walk distanc or where i can take uh',
#  'could you pleas give us some more inform on gerti',
#  'uh i would like to go for lunch uh to some mexican place loudbreath',
#  'well uh loudbreath not veri much loudbreath someth in the up to ten dollar rang',
#  'uh actual i have a car avail now so my friend can take me to um anywher within the east bay area',
#  'i havent yet tri cactu taqueria so could you pleas give me um some addit inform on it',
#  'uh thank you for thi inform but could you pleas tell me if they uh serv alcohol or not',
#  'could i pleas see a list of um mexican restaur that i ask for befor',
#  'could you possibl recommend ani place yourself',
#  'thank you veri much and goodby',
#  'loudbreath lipsmack im look for a thai restaur that is not too expens and is on south side',
#  'loudbreath lipsmack um for dinner on the weekend that doesnt requir reserv laughter',
#  'loudbreath id like some inform on chaam laughter thai restaur',
#  'im look for a restaur for my parent when they come into town um lipsmack italian food um dressi casual',
#  'lipsmack loudbreath would be for dinner on a friday or saturday even',
#  'lipsmack loudbreath um my parent would be will to spend fifteen to twenti five dollar on entre um',
#  'lipsmack loudbreath um we have an automobil so we can go anywher within the berkeley area doesnt matter how far and a resta',
#  'loudbreath tell me more inform on ristorant venezia',
#  'um lipsmack w laughter loudbreath show me the list loudbreath well no what i want to do wa um',
#  'start over laughter loudbreath show me the list',
#  'loudbreath tell me about the music offer cafe',
#  'loudbreath tell me about cafe milano',
#  'start over laughter loudbreath um show me the list',
#  'lipsmack im look for a greek restaur um casual for the weekend even um that between the',
#  'loudbreath i dont want to travel ani further than ten minut from icsi',
#  'tell me more inform about vasiliki',
#  'loudbreath do you need reserv for thi restaur',
#  'lipsmack loudbreath im look for a fun um mostli colleg crowd loudbreath mexican food restaur that cheap',
#  'lipsmack it would be for the weekend um i would prefer it to be no more that ten minut away from icsi',
#  'beep lipsmack loudbreath tell me more about manuel',
#  'beep start over',
#  'im look for oh you dont have anyth about locat like hearst avenu finish laughter loudbreath',
#  'comput alright im realli hungri today for some thai food loudbreath and uh ive got about three and half dollar to spend',
#  'less than ten minut distanc in term of time too',
#  'i have id like to spend less than six dollar',
#  'okay i can spring for ten dollar today',
#  'tell me about nakapan',
#  'tell me about plearn thai cuisin',
#  'id like to eat mexican food today',
#  'i onli have five dollar and i dont have a lot of time so less than five minut',
#  'show me all the mexican restaur',
#  'what good at cactu taqueria',
#  'show me all the barbecu place within fifteen minut of ickse',
#  'im interest in lunch and dinner',
#  'up to fifteen dollar',
#  'show me all the barbecu restaur',
#  'show me all the mexican restaur within fifteen minut drive of ickse',
#  'show me the santaf bar and grill',
#  'um im look for an indian restaur',
#  'a um loudbreath um an even buffet friday or saturday',
#  'uh about fifteen dollar per person',
#  'within three mile of icsi',
#  'um doe maharani serv vegetarian food',
#  'um uh comput um uh are there ani fanci restaur in berkeley',
#  'with california cuisin',
#  'um dinner time',
#  'um lipsmack within an hour of ickse nois',
#  'tell me more about christoph cafe',
#  'um show me the list',
#  'uh do ani of the restaur on the list take credit card unintellig',
#  'which restaur on the list are open on sunday',
#  'um uh find me restaur that are on sanpablo avenu',
#  'um are there ani restaur that are mexican and vegetarian',
#  'weeknight dinner',
#  'um a cheap restaur',
#  'um lipsmack within loudbreath walk distanc of ickse',
#  'tell me more about aycaramba',
#  'oh um pleas show me the li',
#  'um tell me more about pasand',
#  'are there ani thai restaur that are open veri late',
#  'um medium price restaur',
#  'i can dri i can drive ani anywher',
#  'which of the restaur on the list are vegetarian',
#  'um are there russian restaur in berkeley',
#  'are there russian restaur in berkeley',
#  'um i want to eat dinner and it can be medium price',
#  'i can drive to dinner',
#  'um tell me more about petrouchka',
#  'um loudbreath unintellig are there',
#  'um are there ani falafel restaur in berkeley',
#  'um are there place to eat breakfast in berkeley',
#  'um are there ani place for breakfast in berkeley',
#  'i would like to walk from ickse and loudbreath spend under fifteen dollar and',
#  'uh show me the inform for meal ticket',
#  'um show me the inform for vasiliki',
#  'uh show me the inform for la tour eiffel',
#  'i am look for a medium price um lipsmack southeast asian type restaur like mayb vietnames or',
#  'dinner def beep uh dinner definit',
#  'actual um anywher is fine probabl west berkeley uh not too far from campu',
#  'okay how about a lower price',
#  'okay how about veri expens',
#  'uh can you recommend ani like particularli good dish there or is it too cheap loudbreath',
#  'im look for dimsum',
#  'how about sushi',
#  'thi will be for uh sunday dinner time',
#  'well mm medium price for sushi i guess',
#  'as far away as possibl',
#  'would i need reserv at sushisho',
#  'could i have that list back again',
#  'how the servic at kirala',
#  'uh how about japanes restaur that do stuff besid sushi',
#  'beep um how about lunch uh probabl lunch friday and sinc it lunch itll be near campu',
#  'ultra cheap',
#  'how about a littl upscal from that',
#  'id like some realli good food on saturday night',
#  'i would like to eat some chines food on saturday night',
#  'id like thai food on friday lunchtim cheap',
#  'uh id like to have indian food uh today',
#  'expens',
#  'do you have anyth about chezpaniss',
#  'like a list for cheap meal veri close to icsi open on sunday',
#  'for thi same case are these two restaur open uh for lunch',
#  'id like to go up to the next higher price categori so not these cheap one but uh just more expens littl bit more expens',
#  'id like a list of restaur that are fairli far from icsi and are moder price not too cheap not too',
#  'for thi same case it need to be sunday night',
#  'can you give me a list of the kind of food that are avail',
#  'pleas give me a list of the food choic',
#  'okay for the same case how about uh thai or uh vietnames or french or italian',
#  'i didnt want the one that were close just the one that are far',
#  'how about italian and quit expens is fine',
#  'where can i go for lunch today',
#  'um i would like to eat french food',
#  'lipsmack loudbreath i would like to spend less than ten dollar',
#  'oh loudbreath i dont wan na travel too far',
#  'um pleas increas the amount that i wan na spend to twenti dollar',
#  'loudbreath um can you give me more inform lipsmack loudbreath on the french restaur',
#  'oh',
#  'loudbreath where can i go to ea',
#  'i wan na eat lunch today',
#  'i wan na spend about five dollar',
#  'lipsmack i dont wan na travel too far',
#  'loudbreath um pleas give me more inform on orient food to go',
#  'loudbreath beep where can i go to have dinner today tonight',
#  'loudbreath i dont care what kind of food i eat',
#  'loudbreath id like to spend less than ten dollar',
#  'i dont care how f how far i travel',
#  'loudbreath lipsmack loudbreath uh can you list the vegetarian restaur',
#  'loudbreath uh can you give me more inform on long life vegi hous and vegi food',
#  'lipsmack loudbreath can you give me inform on the restaur call vegi food',
#  'im look for an inexpens orient restaur that veri close',
#  'loudbreath id like a chines restaur that near by and is open all week',
#  'tell me more about orient food to go pleas thank',
#  'lipsmack im look for some pizza and id like it to be somewher near by',
#  'id like to have pizza for lunch',
#  'lipsmack id like the most expens pizza that i can get for lunch',
#  'id like some veri expens pizza that far away from here pleas',
#  'loudbreath id like to have my expens pizza for lunch pleas',
#  'id like some expens pizza that far away for dinner pleas',
#  'id like some thai food that near by but not plearn pleas',
#  'id like to spend a medium amount of money pleas',
#  'id like to have thai food for lunch pleas',
#  'id like some northern italian food uh for dinner but i dont wan na make a reserv',
#  'what other italian restaur are near caff venezia',
#  'im look for a croissant um somewher near by and inexpens uh for breakfast',
#  'id like some french food that far away and expens and not a famili restaur becaus i hate',
#  'i want to find a restaur where i can have dinner with a friend',
#  'um i prefer to have orient food',
#  'uh think i can spend up to ten dollar per person',
#  'um we have a car so mayb we can drive for around ten or fifteen minut from ickse',
#  'thi the list is too long um i want onli japanes food',
#  'can you give me some recommend which one serv better sushi',
#  'um do you know what type of food they serv in kirala',
#  'um i want a place where i can have ice cream',
#  'can you tell me uh which cafe that i can go to uh friday even after six',
#  'i want to spend less than five dollar',
#  'um i can drive so it can be anywher',
#  'can you show me th uh more inform about intern hous cafe',
#  'can i see the list pleas',
#  'can you show me what you know about cafe durant',
#  'could i see that uh list of restaur again',
#  'do you have ani inform more inform on manuel',
#  'i want to tri some south american food',
#  'i like to eat sometim thi even',
#  'what i had in mind wa somewher between five and ten dollar inexpen',
#  'i have no constraint about distanc from icsi',
#  'do you have a telephon number for thi cafe violeta',
#  'how mani chines restaur are there in berkeley',
#  'i ask for the number of chines restaur in',
#  'i am interest in a good chines dinner',
#  'i definit do not want to have uh cheap chines food',
#  'i would like to walk no more than ten minut',
#  'what day of the week is hongfu open',
#  'is the hongkong villa open on tuesday',
#  'im interest in',
#  'im look for a good place to eat breakfast',
#  'ani kind of food except uh orient',
#  'you should not constrain the cost at all',
#  'not too far somewher between five and ten minut',
#  'what kind of food doe the continent garden featur',
#  'i wan na take someon for dinner in a realli fanci place',
#  'lipsmack id like to find a restaur to eat in on saturday',
#  'i believ id like to eat some italian food',
#  'id like to spend less than ten dollar',
#  'i dont realli care as long as it near um berkeley as long as it in berkeley',
#  'could you give me some more inform on caff giovanni',
#  'i want to eat some italian food',
#  'id like to eat tonight at six',
#  'i wan na spend ten dollar a plate',
#  'how about three block',
#  'what are what is thi restaur hour',
#  'are there ani persian restaur in berkeley',
#  'are there ani ethiopian restaur in berkeley',
#  'tomorrow even',
#  'ani amount',
#  'anywher in berkeley',
#  'how mani peopl can uh the casbah handl',
#  'loudbreath id like to know all the restaur around here that i can eat veri quickli at',
#  'no more than ten dollar',
#  'beep right now',
#  'which one is closest to here',
#  'uh i onli want restaur that are within two minut walk from here',
#  'i said two minut not five',
#  'lipsmack tell me about orient food to go',
#  'loudbreath lipsmack what the best french restaur around',
#  'lipsmack i want to go and have dinner tomorrow',
#  'doesnt matter',
#  'anywher',
#  'tell me about alacart',
#  'tell me about the other one',
#  'tell me about cambodian restaur in berkeley anywher in berkeley',
#  'anytim make it cheap too',
#  'tell me about cambodiana',
#  'tell me about all of the cambod um let see uh the veg',
#  'could you tell me inform about laval',
#  'tell me about all of the european restaur',
#  'uh could you give me inform about petrouchka',
#  'could you print the menu for vasiliki',
#  'beep yuck uh what smorgasbord restaur are around',
#  'im look for a place where i can get a burrito',
#  'im look for mexican food',
#  'i want to eat at lunch time loudbreath or dinner time or even breakfast',
#  'loudbreath i dont have much money i want to spend veri littl',
#  'loudbreath i dont want to travel veri far from icsi it should be walk distanc',
#  'lipsmack tell me more about aycaramba',
#  'loudbreath tell me more about manuel',
#  'um so i i wa kid i realli want thai food',
#  'or should i say start over start over okay loudbreath comput',
#  'loudbreath um im look for a thai restaur within walk distanc from icsi i want to eat lunch',
#  'it should be reason cheap not veri cheap',
#  'pleas tell me everyth you know about plearn',
#  'hi pleas show me that list again',
#  'thank dude',
#  'um a french restaur close to icsi',
#  'um i want to eat at seven oclock and i want to spend ten dollar a person',
#  'um french food um dinner um twenti dollar',
#  'um tell me more about metropol',
#  'um dinner wednesday um thirti dollar each',
#  'um italian food',
#  'travel doesnt matter um',
#  'um ristorant venezia',
#  'um gim me inform on sujat sujatha',
#  'gim me inform on sujatha',
#  'gim me inform on maharani',
#  'indian restaur for dinner twelv dollar um within five minut from icsi',
#  'distanc from icsi um twenti minut',
#  'list all russian place',
#  'gim me inform on petr petrouchka',
#  'inform on petrouchka',
#  'um american food breakfast uh six dollar twenti minut from icsi',
#  'i need to find a japanes restaur um for lunch twelv dollar a person and twenti minut from the icsi',
#  'im look for a restaur that serv mexican food',
#  'i want to eat on friday night around seven oclock',
#  'i want to spend about ten dollar a person',
#  'i wan na travel around a mile from icsi',
#  'could i have more inform on mario la fiesta',
#  'could you give me a list of chines restaur that er cost around fifteen dollar a per',
#  'i want to eat in the afternoon for lunch',
#  'one about five minut walk from icsi',
#  'could i have an addit inform on orient food to go',
#  'loudbreath id like to eat some indian food tonight',
#  'less than twelv dollar a head',
#  'lipsmack i dont realli care',
#  'lipsmack id like to take a friend for some vietnames lunch today',
#  'lipsmack less than twenti four dollar total',
#  'lipsmack loudbreath less than ten minut',
#  'id like to take my father for an expens french dinner tonight',
#  'lipsmack i dont care',
#  'loudbreath lipsmack loudbreath show me more about the metropol',
#  'lipsmack um',
#  'lipsmack show me all the thai restaur in berkeley',
#  'show me more on siam cuisin',
#  'i feel like eat indian food today',
#  'id like to eat indian food',
#  'what bombay cuisin like',
#  'i would like to eat chines food',
#  'i want to eat thi even',
#  'i want to spend lot of money',
#  'i want it to be within walk distanc ten minut or so',
#  'i dont mind a cheap restaur',
#  'what hongkong villa like',
#  'lipsmack i wannu eat uh somewher realli nice',
#  'lipsmack loudbreath id like to eat french cuisin or california cuisin or someth like that',
#  'lipsmack loudbreath i want to eat thi even',
#  'ive got a car so i can go anywher in berkeley',
#  'tell me some more about omnivor',
#  'tell me about chezpaniss',
#  'that wa chezpaniss cafe what about chezpaniss',
#  'okay that one look pretti good end of session',
#  'are there ani austrian restaur in berkeley',
#  'pleas show me a list of all italian restaur',
#  'are there ani restaur open after midnight',
#  'i do not want to spend too much money',
#  'that doe not matter i have a car',
#  'can i get spaghetti in the caff giovanni',
#  'which are the oh which are the cheapest place near icsi where i go can go for lunch',
#  'uh which are the most afford place close to icsi for lunch',
#  'ani food is good for me',
#  'i want to spend five dollar',
#  'what type of food do you get at la tour eiffel',
#  'can you show me the list of restaur again',
#  'addison annex',
#  'do you know mel restaur',
#  'which restaur is farthest away from icsi',
#  'where do i get german food',
#  'where can i get egyptian or arabian food',
#  'is there a middl eastern restaur',
#  'i would like to eat in the morn',
#  'that doesnt matter',
#  'i would like to have dinner',
#  'uh show me la mediterrane',
#  'um id like to go out for lunch for taiwanes food',
#  'lipsmack loudbreath id like to spend about six dollar each meal',
#  'lipsmack loudbreath id like to walk about five to ten minut',
#  'lipsmack can i have more inform about thi taiwan restaur',
#  'lipsmack pleas can i see the menu of thi restaur',
#  'lipsmack loudbreath id like to go out for asian lunch',
#  'oh no i plan to spend about six dollar',
#  'i dont wan na walk more than ten minut',
#  'loudbreath uh give me more inform about the cambodiana restaur',
#  'lipsmack pleas show the list again',
#  'loudbreath i want more inform about the thai barbecu restaur',
#  'lipsmack id like to go out into american restaur',
#  'lipsmack id like to have a list of the german restaur',
#  'lipsmack loudbreath id like to get a list of the japanes restaur',
#  'right now laughter laughter laughter laughter laughter laughter laughter',
#  'about si six dollar',
#  'not more than ten minut',
#  'loudbreath i still wan na go to a japanes restaur i wan na spend not more than ten dollar and i dont wan na drive',
#  'lipsmack loudbreath i wan na spend six to twelv dollar',
#  'i wan na drive le drive less than ten minut',
#  'loudbreath where do they ha which restaur ha sushi',
#  'where the nicest waiter laughter',
#  'i like to go out for mediterranean food',
#  'in ten minut',
#  'i wan na spend between six and ten dollar',
#  'less than ten minut',
#  'um i can spend whatev money it cost',
#  'lipsmack loudbreath distanc can be up to twenti minut walk',
#  'loudbreath i wan na go for dinner to that restaur',
#  'lipsmack thi is the end',
#  'oh mm id like to find out all greek restaur',
#  'on sunday or saturday night',
#  'not more than twenti dollar for a meal',
#  'not more than thirti minut by car',
#  'pleas tell me more about the restaur vasiliki loudbreath loudbreath',
#  'pleas tell me more about vasiliki uh unintellig',
#  'tell me all greek restaur in berkeley',
#  'id like to have inform about chines restaur',
#  'i want to know all chines restaur where the meal is less than five dollar',
#  'im abl to travel up to thirti minut',
#  'lipsmack are there ani german restaur',
#  'is there ani restaur with import beer',
#  'where can i have rose wine',
#  'is there a restaur with have more than hundr place',
#  'loudbreath i need a restaur with more than hundr place oh',
#  'i like californian food',
#  'i want to eat each day',
#  'i like chines food uh could you make me some propos',
#  'um i would like to go for dinner tonight to chines restaur',
#  'not too much mayb between five and eight dollar per person',
#  'i have a car so i dont care',
#  'tell me more about orient food to go',
#  'uh i would like to have sushi today for lunch',
#  'i do not know i do not want to know anyth more about chines restaur i want to know about sushi',
#  'do you know about a place call sushiko',
#  'uh i guess the french cuisin is the best all over the world do you have someth appropri for me',
#  'pleas show me french restaur in berkeley',
#  'i would like to go for dinner tomorrow night to a french restaur',
#  'i would spend until twenti dollar per person and it should be',
#  'should be in drive distanc',
#  'tell me more about that la tour eiffel',
#  'what can you tell me about i think it wa call mm metropol',
#  'give me the list of all french restaur in berkeley',
#  'i want to to eat european food',
#  'i want to eat in the even',
#  'let say up to fifteen dollar',
#  'i want to travel up to three kilomet',
#  'lipsmack tell me a littl bit more about nadin',
#  'im look for a restaur',
#  'i would like to eat american food',
#  'i want to do it in the even',
#  'up to ten dollar',
#  'two kilomet',
#  'give me a littl bit more inform about top dog',
#  'i want to go for breakfast in the surround of the icsi',
#  'id like to eat mexican',
#  'up to twenti dollar',
#  'id like to have european breakfast',
#  'it could be in a surround of five kilomet',
#  'lipsmack loudbreath are there ani chines restaur within walk distanc of icsi',
#  'in the earli even',
#  'not more than beep ten dollar',
#  'lipsmack loudbreath do ani of the restaur on thi list serv vegetarian food',
#  'doe hongkong villa serv spici szechuan cuisin',
#  'are ani of the restaur on the list open in the morn',
#  'list me all the german restaur in berkeley',
#  'my inlaw will visit me next weekend and i would like to take them to a indian restaur uh ani suggest',
#  'lipsmack loudbreath my budget is veri limit and i dont want to spend more than five dollar',
#  'it should prefer be within walk distanc',
#  'lipsmack loudbreath which of these two restaur serv uh southern indian cuisin',
#  'show me the list again',
#  'i have been told that the first restaur on the list serv so south indian uh dish',
#  'do you know of ani restaur that serv pickl pig feet',
#  'how about boil pig feet that a german delicaci',
#  'the list restaur s dont sound like german restaur can you show me an excerpt of their menu',
#  'can you at least list the nation of these restaur',
#  'my wed anniversari is come up and i would like a list of the realli fanci restaur',
#  'the kind of food doesnt matter as long as it is expens',
#  'loudbreath thi saturday night',
#  'distanc doesnt matter were gon na take a chauffeur limousin',
#  'pleas list onli those restaur in the highest price categori',
#  'can you give me some more inform on the metropol restaur',
#  'thank you',
#  'im veri hungri today and i want to go to dinner thi even',
#  'mayb asian food or african would would be fine',
#  'it shouldnt be m more than ten dollar includ all the drink',
#  'distanc is no problem becaus i have a fast car mayb not more than twenti minut with a car',
#  'how about the blue nile it sound veri good could you show me a menu',
#  'show me the list pleas',
#  'can you give me some more inform about the shinshin pleas',
#  'shinshin look fine can you pleas m make a reserv for a tabl thi even at seven',
#  'i want to go to lunch today and im not familiar with berkeley at all it shouldnt be far away',
#  'i would like german food especi bavarian is my prefer kind of food',
#  'okay then let let tri middl european',
#  'money no problem it ha to be expens becaus i have a veri prosper guest with me',
#  'let tri the metropol at shattuck',
#  'i like fre french food a lot pleas make a reserv for thi even for a tabl for two person at eight',
#  'can you show me the list again',
#  'how about caff venezia do they have tortellini',
#  'pleas cancel the reserv w um at the other restaur i would prefer caff venezia',
#  'lipsmack loudbreath lipsmack i want to go to eat some african food today',
#  'i want to eat on saturday',
#  'loudbreath i like to spend ten dollar',
#  'i want to go not f f um farther than ten minut',
#  'loudbreath lipsmack loudbreath how about if the distanc is about half an hour',
#  'loudbreath pleas provid me some more inform about blue nile',
#  'lipsmack loudbreath lipsmack i wan na go for italian dinner',
#  'lipsmack i wan na go today',
#  'loudbreath i wan na spend less than ten dollar for us both',
#  'loudbreath it should be veri close to ic icsi',
#  'loudbreath lipsmack let tri it with fast food',
#  'loudbreath no i dont like pizza',
#  'loudbreath lipsmack so what about russian dinner',
#  'so i would spend more than twelv dollar for us both',
#  'lipsmack i would go a distanc of five minut',
#  'so i would go a distanc of six minut',
#  'loudbreath lipsmack so provid me some more inform about the ristorant ristorant venezia',
#  'i would like to uh have dinner on saturday in berkeley',
#  'i would like to have a famou um american restaur',
#  'oh i dont know how much money i need for a uh excel dinner',
#  'oh it shouldnt be too far away from icsi loudbreath probabl a mile or so',
#  'i would like to uh get you help in take ani cost uh for thi',
#  'tell me about soup kitchen heik',
#  'give me onc more the list pleas',
#  'how about saul deli',
#  'tell me tell me what saul deli is like',
#  'do you have a uh list of the avail uh meal at saul deli',
#  'let tri it again can you tell me the type of cours i can get at that restaur',
#  'start over pleas',
#  'let have a uh nice french restaur',
#  'i still want to have dinner on saturday',
#  'take ani of the categori',
#  'i will stay with thi one mile from icsi',
#  'how about la tour eiffel',
#  'how about chezpaniss',
#  'do you have a uh list of the meal at chezpaniss',
#  'do you have other gourmet restaur californian style',
#  'howbout',
#  'do you have other charm restaur',
#  'do you have restaur for napav',
#  'do you have uh cafe in your list',
#  'i want to eat on wednesday for lunch',
#  'i dont mind about the money',
#  'i dont mind about the length of the travel',
#  'excel',
#  'uh i would like to find a place uh for lunch today',
#  'is there ani good place for thai food',
#  'uh actual i want to spend about ten dollar maximum',
#  'the place should be reachabl within ten minut',
#  'uh i would like to know more about thai barbecu',
#  'uh can i have the list again',
#  'uh what about nakapan',
#  'uh give me back the list',
#  'um there is a place it call like plearn thai cuisin just give me more detail about that',
#  'pleas the list',
#  'uh give me more detail about thai barbecu',
#  'uh start over',
#  'i would like to go out for dinner in some italian place',
#  'uh around thirti dollar',
#  'walk distanc',
#  'tell me more about caff venezia',
#  'i like to go to a japanes restaur for lunch',
#  'around fifteen dollar',
#  'fifteen minut',
#  'uh tell me more about joshuya',
#  'lipsmack loudbreath i like to go to pizza place for lunch',
#  'three dollar',
#  'five minut',
#  'i would like to take my mother out for dinner to an indian restaur',
#  'i dont have much money to spend let say no more than twenti dollar',
#  'i dont have a car so we are go to walk let say no more than ten secon ten minut oh',
#  'i would like to eat someth tomorrow morn somewher in berkeley',
#  'uh american breakfast',
#  'uh no more than ten dollar',
#  'as close as possibl',
#  'uh at what time uh doe thi restaur open',
#  'so i would like uh thi time to go to an italian restaur',
#  'uh in the late even',
#  'uh fifti dollar',
#  'doesnt realli matter',
#  'uh well i dont care about the cost you could give me more restaur',
#  'okay uh could you give me a list of uh veri expens restaur but i dont care about uh which kind of food',
#  'tap uh i would like uh a list of veri expens restaur in berkeley',
#  'uh it doesnt matter uh which kind of food',
#  'um doesnt matter when i like just to have a list of veri expens restaur',
#  'uh as far as you want',
#  'uh just cut down the list to the most expens restaur',
#  'i would like to have some more inform about fondu fred in telegraph avenu',
#  'w which kind of food is the swiss food',
#  'uh s so uh what the price for an averag meal in thi restaur',
#  'uh could you pleas show me the list again',
#  'some more inform about restaur in solano avenu',
#  'could you go back to the list',
#  'uh i like to see onli uh restaur in shattuck avenu',
#  'id like to have uh a list of restaur in berkeley uh italian restaur',
#  'what the cheapest italian restaur in berkeley tap',
#  'id like to go to a restaur in for the dinner',
#  'just five minut far from ickse by walk',
#  'a restaur where i can spend six to twelv dollar',
#  'a restaur that i can reach by car in five minut tap',
#  'id like to have more inform about the restaur caff giovanni tap',
#  'uh id like to go to a chines restaur',
#  'id like to take a dinner',
#  'id like to go to the most expens re uh chines restaur in berkeley loudbreath',
#  'it doesnt matter the distanc from ickse tap',
#  'it doesnt matter the cost of the restaur',
#  'where can i have a vegetarian dinner',
#  'uh what a restaur a chines restaur where i can have a uh vegetarian dinner',
#  'what the closest french restaur to ickse',
#  'it doesnt matter the cost',
#  'what the close day of metropol',
#  'give me inform about la tour eiffel',
#  'what are the other uh what are the other french restaur in berkeley',
#  'it doesnt matter the distanc from ickse',
#  'what about alacart tap',
#  'i dunno what laughter laughter uh',
#  'what about aucoquelet',
#  'what about aucoquelet',
#  'can you give me a list of portugues restaur',
#  'can you give me list of uh japanes restaur on telegraph',
#  'just for lunch',
#  'doesnt matter the cost',
#  'i would like to go on telegraph',
#  'id like to go to a ja a japanes restaur five minut from ickse spend uh not',
#  'we like to go to a chines restaur five minut far from ickse for dinner spend not a lot of money',
#  'id like to go to a chines restaur five minut from ickse loudbreath not spend a lot of money',
#  'for breakfast',
#  'i want to find a place where i can eat japanes food',
#  'i want to go out for dinner',
#  'say twenti dollar per head',
#  'say about uh five mile radiu',
#  'i dont care about the cost',
#  'could you tell me a littl more about joshuya',
#  'could you show me the list',
#  'tell me a littl more about kirala',
#  'could you tell me a littl more about sushiko',
#  'i want to find out about italian restaur in the area',
#  'i want to find out about dinner',
#  'i dont care about the money',
#  'it should be in the neighborhood of berkeley',
#  'it should be in the neighborhood of berkeley',
#  'tell me a bit more about caff venezia',
#  'id like to go to a fanci restaur',
#  'id like french food',
#  'next thursday',
#  'dinner',
#  'i want to eat french food',
#  'i want to have dinner',
#  'it can be realli expens',
#  'as far away as we can get',
#  'i want to be far away from icsi',
#  'tell me about le bateau ivr',
#  'tell me about alacart',
#  'show me the list again',
#  'let me see the list again',
#  'i want the restaur to be realli close to icsi',
#  'i want to eat breakfast instead',
#  'start over',
#  'i want to eat breakfast at a realli cheap place tomorrow',
#  'thi is for breakfast',
#  'what kind of food do you know about',
#  'i want to eat american food',
#  'a moder distanc away',
#  'about fifteen minut',
#  'fifteen minut away',
#  'i said fifteen minut laughter',
#  'within half a mile from ickse',
#  'loudbreath tell me about sandwich agogo',
#  'sandwich agogo',
#  'show me the list pleas',
#  'um id like to know more about the homemad cafe',
#  'start over',
#  'i wan na eat some realli cheap chines food right now',
#  'i want it to be lunch',
#  'about twenti minut walk',
#  'tell me about sunhongkong',
#  'sunhongkong',
#  'tell me about blue nile',
#  'start over',
#  'i want to go to a vegetarian restaur',
#  'i want to eat next monday i want to have dinner',
#  'dinner pleas',
#  'it doesnt realli matter',
#  'i want it to be close by here',
#  'i said i want it to be close by laughter',
#  'close by',
#  'about five minut walk from icsi',
#  'tell me about plearn thai cuisin',
#  'let me see the list again',
#  'tell me about the pizza place',
#  'jupit',
#  'start over',
#  'tell me about greek restaur in berkeley',
#  'i want to eat dinner today',
#  'dinner and i dont care how much it cost',
#  'dinner',
#  'i want to eat dinner tonight nois',
#  'i want greek food and i want to eat dinner',
#  'i dont care what meal',
#  'it doesnt matter',
#  'i dont care',
#  'doesnt matter',
#  'end of session',
#  'can you tell me ehm what good french restaur there are in the area',
#  'i would like to spend about twenti dollar for dinner on a saturday night',
#  'what els can you tell me about the metropol',
#  'can you give me more inform about latoureiffel',
#  'can you return to the menu of all restaur',
#  'can you return to the list eh',
#  'can you give me more inform on arinel pizza',
#  'can you give me inform on japanes food',
#  'can you tell me more about',
#  'start over',
#  'yeah my parent are come into town and theyr pay so id like to go to a realli nice restaur california cuisin for dinner',
#  'i want to eat california food and um it doesnt realli matter where it is',
#  'uh theyll be here two week from saturday so that would be good and anytim in the even would be fine',
#  'i want california cuisin and i want it a week from saturday loudbreath',
#  'whi dont you just tell me about cafe pastor',
#  'start over',
#  'id like to go out for lunch today uh cheap chines food would be good no no make that thai loudbreath',
#  'i want cheap thai food and im in a hurri so it should be close to ickse and it should be fast',
#  'i said i want cheap thai food',
#  'i want to eat today',
#  'i want to eat today real soon',
#  'start over',
#  'yeah id like to go out thi sunday for omelet and cappuccino somewher in north berkeley',
#  'cappuccino for breakfast on sunday',
#  'loudbreath well what are omelet anyway uh i guess it could be french or california or just plain old american',
#  'start over',
#  'start over',
#  'yeah i want to take uh my girlfriend out for sushi',
#  'uh thi would be next tuesday uh say between seven and eight oclock at night and well be go from work so i dont want it',
#  'start over',
#  'start over',
#  'what place ha the best croissant in berkeley',
#  'i want the best croissant',
#  'whi dont we just go out for pizza instead',
#  'uh my friend and ill be get togeth tonight round six pm',
#  'so it would be realli good',
#  'start over',
#  'are there ani restaur in town that serv middl eastern food',
#  'i want to go out for dinner thi friday and uh ive got a car so it doesnt realli matter how far it is',
#  'eat thi friday',
#  'eat thi friday',
#  'friday dammit',
#  'oh weve somebodi on an expens account so money is no no matter',
#  'weve got a car so i dont care how far we have to go',
#  'matter how far we have to go',
#  'lipsmack hello i would like to um eat next saturday italian food',
#  'lipsmack i would like to eat on saturday',
#  'uh i would like to have um lunch',
#  'lipsmack i want to spend about fifteen buck',
#  'i want to spend fifteen dollar',
#  'i want to spend fifteen dollar',
#  'i want to spend twelv dollar',
#  'i want to spend twelv buck',
#  'i dont want to spend more than twelv buck',
#  'doesnt matter',
#  'it doesnt matter',
#  'expens',
#  'lipsmack i would like to go uh on next wednesday',
#  'hello i would like to eat some indian food',
#  'i would like to eat on next tuesday',
#  'i would like to eat um to have dinner',
#  'i would like to have dinner',
#  'i would like to have dinner',
#  'uh i want to have breakfast',
#  'it doesnt matter',
#  'as possibl',
#  'cheap',
#  'um ten minut',
#  'um i dont want to have breakfast i want to have dinner',
#  'i want to eat at um',
#  'i want to eat at eight oclock in the even',
#  'at eight oclock in the even',
#  'i like to have dinner',
#  'uh i like to have lunch',
#  'start over',
#  'start over',
#  'start over',
#  'i like to eat mexican food thi night',
#  'thi night and uh i like to spend no more than forti dollar',
#  'i like to eat thi night and not far from seven eight mile',
#  'not more than ten mile',
#  'from five to ten mile',
#  'can i have the list of food of viva taqueria',
#  'can i have the list of food of vi viva taqueria',
#  'start over',
#  'i like to have uh dinner uh wednesday night of thai food',
#  'wednesday night',
#  'i dont want to spend more than forti dollar',
#  'not more than an hour',
#  'less than one hour',
#  'less than one hour',
#  'not more than twenti mile',
#  'i like inform about berkeley thai hous',
#  'id like to tri someth uh east asian',
#  'id like some chines food',
#  'i want to eat today',
#  'i want to eat today',
#  'i want to eat lunch',
#  'oh i dont want to spend much',
#  'i dont have much money',
#  'i want to spend a lot of money',
#  'i have no money',
#  'i want to spend five dollar',
#  'some place within walk distanc',
#  'i wan na know if sunhongkong ha uh let see what do i want i want to know if they have oh saday beef chowfun',
#  'well tell me if you like orient food to go',
#  'im will to spend a lot of money',
#  'im will to spend a lot of money',
#  'ill pay up to twenti dollar',
#  'im will to drive',
#  'i want to go somewher within drive distanc',
#  'i have a car',
#  'i said ive got a car',
#  'im speak clear english now right so i say ive got a car and so im will to drive so take me somewher further than five mi',
#  'i wan na burrito',
#  'i want someth cheap',
#  'i dont have a car',
#  'thi place should be in walk distanc',
#  'are the waitress pretti at aycaramba',
#  'tell me about the other one',
#  'aucoquelet',
#  'my friend here like italian food',
#  'howbout thai food',
#  'im will to pay ten dollar or so',
#  'tell me everyth you know about thai barbecu',
#  'nois nina think your total cool',
#  'im into chines',
#  'start over',
#  'im look for some place to take somebodi picki',
#  'i wan na eat realli good food i dont care how much it cost',
#  'i want veri high qualiti food someth realli tasti',
#  'like to go some place expens',
#  'hi id like to get anyth except italian food',
#  'okay look i wan na eat dinner tonight and i want to spend thirti dollar okay',
#  'like to spend up to thirti dollar and im a vegetarian',
#  'how about someth farther away',
#  'i want to drive there in a car',
#  'i dont care whether it close or not',
#  'is there ani place around here with entertain',
#  'start over',
#  'start over',
#  'id like to go some place with a bar',
#  'is there ani place that ha a full bar and coffe',
#  'i just wan na get like drink and snack although my friend here want a sandwich',
#  'id like sandwich and coffe',
#  'is there ani place for dinner that isnt close on monday',
#  'id pay a lot',
#  'ill spend ani amount of money for good vietnames food',
#  'i could go veri far',
#  'start over',
#  'i have to be on the road by eight am',
#  's pleas',
#  'id like to get breakfast',
#  'i wan na eat today',
#  'can i go to just like a normal american restaur mayb a diner',
#  'id like to spend i dont know under ten buck someth like that',
#  'i could spend under ten buck',
#  'okay i could spend under ten dollar',
#  'id be will to shell out anyth up to about uh ten semolian laughter nois',
#  'so which one of these place is realli good',
#  'howbout an american restaur',
#  'start over',
#  'id like to go for dinner to kind of upscal yuppi california cuisin kind of place',
#  'i want a california cuisin restaur pleas',
#  'i want dinner on friday night and no reserv',
#  'i could take a date',
#  'i dont care',
#  'i dont care',
#  'i dont care about that either',
#  'so which is the cheapest',
#  'start over',
#  'id like a veri authent mexican restaur',
#  'i want like just an authent mexican restaur with burrito and mayb no seat',
#  'is there a take out place',
#  'whi wont it stop',
#  'so i just want to go some place quick for lunch get a sandwich bring it back to my desk',
#  'lunch today would be just fine',
#  'im on foot so it better be close',
#  'laughter so howbout a cheap greek restaur',
#  'about that sleazi souvlaki place on shattuck that nobodi ever goe into',
#  'uh i wish to have some uh fish and chip',
#  'i want to have fish and chip',
#  'fish and chip',
#  'american food',
#  'i wish to eat american food',
#  'i wish to eat american food',
#  'sunday',
#  'i wish to eat brunch',
#  'where can i uh drink a coffe',
#  'where can i drink a coffe',
#  'where can i drink a coffe',
#  'where can i have a cup of coffe',
#  'go for coffe',
#  'go for cafe',
#  'i want to go to a unintellig',
#  'which one is the closest to ickse',
#  'which one is the closest to icsi',
#  'which one is the cheapest',
#  'i want to eat uh some fruit',
#  'i wish to have a plate of spaghetti',
#  'i want to have a plate of spaghetti',
#  'do you know where i can eat spaghetti',
#  'do you know where i can find uh an italian restaur',
#  'do you know cough whe uh',
#  'i want to eat italian food',
#  'i want to eat italian food',
#  'i want to eat italian food',
#  'i want to eat italian food',
#  'i want to eat it italian food',
#  'i want spend a lot of money',
#  'i want an expens restaur',
#  'i want an expens restaur',
#  'where can i uh eat a taco',
#  'i want to have some taco',
#  'where can i eat some taco',
#  'i want to eat mexican food',
#  ...]

# %%
bi = list(map(bigrams,corpus))

# %%
bi
# Out:
# [[('<sos>', 'okay'),
#   ('okay', 'let'),
#   ('let', 'see'),
#   ('see', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'go'),
#   ('go', 'to'),
#   ('to', 'a'),
#   ('a', 'thai'),
#   ('thai', 'restaur'),
#   ('restaur', 'uh'),
#   ('uh', 'with'),
#   ('with', 'less'),
#   ('less', 'than'),
#   ('than', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'per'),
#   ('per', 'person'),
#   ('person', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'uh'),
#   ('uh', 'i'),
#   ('i', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'at'),
#   ('at', 'lunch'),
#   ('lunch', 'time'),
#   ('time', 'so'),
#   ('so', 'that'),
#   ('that', 'would'),
#   ('would', 'be'),
#   ('be', 'eleven'),
#   ('eleven', 'am'),
#   ('am', 'to'),
#   ('to', 'one'),
#   ('one', 'pm'),
#   ('pm', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'dont'),
#   ('dont', 'want'),
#   ('want', 'to'),
#   ('to', 'walk'),
#   ('walk', 'for'),
#   ('for', 'more'),
#   ('more', 'than'),
#   ('than', 'five'),
#   ('five', 'minut'),
#   ('minut', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'the'),
#   ('the', 'uh'),
#   ('uh', 'na'),
#   ('na', 'nakapan'),
#   ('nakapan', 'uh'),
#   ('uh', 'restaur'),
#   ('restaur', 'on'),
#   ('on', 'martin'),
#   ('martin', 'luther'),
#   ('luther', 'king'),
#   ('king', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'to'),
#   ('to', 'a'),
#   ('a', 'hamburg'),
#   ('hamburg', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'let'), ('let', 'start'), ('start', 'again'), ('again', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'like'),
#   ('like', 'to'),
#   ('to', 'get'),
#   ('get', 'a'),
#   ('a', 'hamburg'),
#   ('hamburg', 'at'),
#   ('at', 'an'),
#   ('an', 'american'),
#   ('american', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'dinner'),
#   ('dinner', 'and'),
#   ('and', 'i'),
#   ('i', 'dont'),
#   ('dont', 'mind'),
#   ('mind', 'walk'),
#   ('walk', 'uh'),
#   ('uh', 'for'),
#   ('for', 'half'),
#   ('half', 'an'),
#   ('an', 'hour'),
#   ('hour', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'dont'),
#   ('dont', 'want'),
#   ('want', 'to'),
#   ('to', 'spend'),
#   ('spend', 'more'),
#   ('more', 'than'),
#   ('than', 'uh'),
#   ('uh', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'for'),
#   ('for', 'a'),
#   ('a', 'hamburg'),
#   ('hamburg', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'the'),
#   ('the', 'two'),
#   ('two', 'barbecu'),
#   ('barbecu', 'restaur'),
#   ('restaur', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'the'),
#   ('the', 'two'),
#   ('two', 'barbecu'),
#   ('barbecu', 'restaur'),
#   ('restaur', 'you'),
#   ('you', 'list'),
#   ('list', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'everett'),
#   ('everett', 'and'),
#   ('and', 'jone'),
#   ('jone', 'barbecu'),
#   ('barbecu', 'flint'),
#   ('flint', 'barbecu'),
#   ('barbecu', 'and'),
#   ('and', 'the'),
#   ('the', 'thai'),
#   ('thai', 'barbecu'),
#   ('barbecu', 'pleas'),
#   ('pleas', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'the'),
#   ('the', 'best'),
#   ('best', 'place'),
#   ('place', 'to'),
#   ('to', 'get'),
#   ('get', 'soup'),
#   ('soup', 'in'),
#   ('in', 'berkeley'),
#   ('berkeley', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'the'),
#   ('the', 'best'),
#   ('best', 'place'),
#   ('place', 'to'),
#   ('to', 'get'),
#   ('get', 'soup'),
#   ('soup', 'in'),
#   ('in', 'berkeley'),
#   ('berkeley', 'for'),
#   ('for', 'lunch'),
#   ('lunch', 'for'),
#   ('for', 'under'),
#   ('under', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'uh'),
#   ('uh', 'with'),
#   ('with', 'a'),
#   ('a', 'ten'),
#   ('ten', 'minut'),
#   ('minut', 'walk'),
#   ('walk', '</sos>')],
#  [('<sos>', 'what'),
#   ('what', 'type'),
#   ('type', 'of'),
#   ('of', 'food'),
#   ('food', 'do'),
#   ('do', 'you'),
#   ('you', 'understand'),
#   ('understand', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'indian'),
#   ('indian', 'food'),
#   ('food', 'and'),
#   ('and', 'i'),
#   ('i', 'have'),
#   ('have', 'chuck'),
#   ('chuck', 'car'),
#   ('car', 'so'),
#   ('so', 'i'),
#   ('i', 'can'),
#   ('can', 'drive'),
#   ('drive', 'in'),
#   ('in', 'but'),
#   ('but', 'i'),
#   ('i', 'onli'),
#   ('onli', 'want'),
#   ('want', 'to'),
#   ('to', 'drive'),
#   ('drive', 'for'),
#   ('for', 'ten'),
#   ('ten', 'minut'),
#   ('minut', 'and'),
#   ('and', 'i'),
#   ('i', 'onli'),
#   ('onli', 'want'),
#   ('want', 'to'),
#   ('to', 'pay'),
#   ('pay', 'five'),
#   ('five', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'what'),
#   ('what', 'about'),
#   ('about', 'the'),
#   ('the', 'indian'),
#   ('indian', 'cafe'),
#   ('cafe', 'can'),
#   ('can', 'you'),
#   ('you', 'give'),
#   ('give', 'me'),
#   ('me', 'inform'),
#   ('inform', 'about'),
#   ('about', 'that'),
#   ('that', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'pasand'),
#   ('pasand', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'moe'),
#   ('moe', 'burger'),
#   ('burger', '</sos>')],
#  [('<sos>', 'a'),
#   ('a', 'cheap'),
#   ('cheap', 'restaur'),
#   ('restaur', 'near'),
#   ('near', 'by'),
#   ('by', 'that'),
#   ('that', 'serv'),
#   ('serv', 'meat'),
#   ('meat', '</sos>')],
#  [('<sos>', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'pork'),
#   ('pork', 'or'),
#   ('or', 'beef'),
#   ('beef', '</sos>')],
#  [('<sos>', 'bacon'),
#   ('bacon', 'and'),
#   ('and', 'egg'),
#   ('egg', 'or'),
#   ('or', 'breakfast'),
#   ('breakfast', '</sos>')],
#  [('<sos>', 'more'),
#   ('more', 'inform'),
#   ('inform', 'about'),
#   ('about', 'addison'),
#   ('addison', 'annex'),
#   ('annex', '</sos>')],
#  [('<sos>', 'yeah'),
#   ('yeah', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'out'),
#   ('out', 'for'),
#   ('for', 'some'),
#   ('some', 'thai'),
#   ('thai', 'food'),
#   ('food', 'uh'),
#   ('uh', 'not'),
#   ('not', 'too'),
#   ('too', 'expens'),
#   ('expens', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'how'),
#   ('how', 'about'),
#   ('about', 'six'),
#   ('six', 'pm'),
#   ('pm', '</sos>')],
#  [('<sos>', 'make'),
#   ('make', 'it'),
#   ('it', 'walk'),
#   ('walk', 'distanc'),
#   ('distanc', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'the'),
#   ('the', 'thai'),
#   ('thai', 'barbecu'),
#   ('barbecu', 'place'),
#   ('place', '</sos>')],
#  [('<sos>', 'yeah'),
#   ('yeah', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'a'),
#   ('a', 'vegetarian'),
#   ('vegetarian', 'place'),
#   ('place', 'that'),
#   ('that', 'open'),
#   ('open', 'on'),
#   ('on', 'wednesday'),
#   ('wednesday', '</sos>')],
#  [('<sos>', 'mm'),
#   ('mm', 'ill'),
#   ('ill', 's'),
#   ('s', 'ill'),
#   ('ill', 'spend'),
#   ('spend', 'a'),
#   ('a', 'lot'),
#   ('lot', 'of'),
#   ('of', 'money'),
#   ('money', 'thi'),
#   ('thi', 'time'),
#   ('time', '</sos>')],
#  [('<sos>', 'doesnt'),
#   ('doesnt', 'matter'),
#   ('matter', 'how'),
#   ('how', 'far'),
#   ('far', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'the'),
#   ('the', 'long'),
#   ('long', 'life'),
#   ('life', 'vegi'),
#   ('vegi', 'hous'),
#   ('hous', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'american'),
#   ('american', 'food'),
#   ('food', 'or'),
#   ('or', 'mexican'),
#   ('mexican', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'um'),
#   ('um', 'eat'),
#   ('eat', 'lunch'),
#   ('lunch', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'have'),
#   ('have', 'lunch'),
#   ('lunch', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'i'),
#   ('i', 'dont'),
#   ('dont', 'want'),
#   ('want', 'to'),
#   ('to', 'spend'),
#   ('spend', 'a'),
#   ('a', 'lot'),
#   ('lot', 'of'),
#   ('of', 'money'),
#   ('money', 'uh'),
#   ('uh', 'so'),
#   ('so', 'someth'),
#   ('someth', 'fairli'),
#   ('fairli', 'cheap'),
#   ('cheap', 'would'),
#   ('would', 'be'),
#   ('be', 'good'),
#   ('good', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wan'),
#   ('wan', 'na'),
#   ('na', 'eat'),
#   ('eat', 'someplac'),
#   ('someplac', 'that'),
#   ('that', 'close'),
#   ('close', 'to'),
#   ('to', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'uh'),
#   ('uh', 'italian'),
#   ('italian', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'i'),
#   ('i', 'i'),
#   ('i', 'dont'),
#   ('dont', 'mind'),
#   ('mind', 'spend'),
#   ('spend', 'a'),
#   ('a', 'lot'),
#   ('lot', 'of'),
#   ('of', 'money'),
#   ('money', 'but'),
#   ('but', 'i'),
#   ('i', 'i'),
#   ('i', 'dont'),
#   ('dont', 'wan'),
#   ('wan', 'na'),
#   ('na', 'i'),
#   ('i', 'dont'),
#   ('dont', 'wan'),
#   ('wan', 'na'),
#   ('na', 'go'),
#   ('go', 'someplac'),
#   ('someplac', 'cheap'),
#   ('cheap', 'i'),
#   ('i', 'guess'),
#   ('guess', 'middl'),
#   ('middl', 'rang'),
#   ('rang', 'would'),
#   ('would', 'be'),
#   ('be', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'i'),
#   ('i', 'dont'),
#   ('dont', 'mind'),
#   ('mind', 'uh'),
#   ('uh', 'have'),
#   ('have', 'to'),
#   ('to', 'drive'),
#   ('drive', 'someplac'),
#   ('someplac', 'doesnt'),
#   ('doesnt', 'have'),
#   ('have', 'to'),
#   ('to', 'be'),
#   ('be', 'close'),
#   ('close', 'to'),
#   ('to', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'need'),
#   ('need', 'to'),
#   ('to', 'find'),
#   ('find', 'a'),
#   ('a', 'uh'),
#   ('uh', 'place'),
#   ('place', 'to'),
#   ('to', 'eat'),
#   ('eat', 'uh'),
#   ('uh', 'for'),
#   ('for', 'next'),
#   ('next', 'uh'),
#   ('uh', 'saturday'),
#   ('saturday', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'uh'),
#   ('uh', 'italian'),
#   ('italian', 'food'),
#   ('food', 'or'),
#   ('or', 'or'),
#   ('or', 'american'),
#   ('american', 'food'),
#   ('food', 'either'),
#   ('either', 'one'),
#   ('one', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'i'),
#   ('i', 'want'),
#   ('want', 'the'),
#   ('the', 'a'),
#   ('a', 'restaur'),
#   ('restaur', 'where'),
#   ('where', 'i'),
#   ('i', 'can'),
#   ('can', 'get'),
#   ('get', 'some'),
#   ('some', 'lunch'),
#   ('lunch', 'um'),
#   ('um', 'tomorrow'),
#   ('tomorrow', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'find'),
#   ('find', 'someth'),
#   ('someth', 'that'),
#   ('that', 'fairli'),
#   ('fairli', 'cheap'),
#   ('cheap', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'id'),
#   ('id', 'like'),
#   ('like', 'someth'),
#   ('someth', 'that'),
#   ('that', 'uh'),
#   ('uh', 'within'),
#   ('within', 'walk'),
#   ('walk', 'distanc'),
#   ('distanc', 'of'),
#   ('of', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'is'),
#   ('is', 'there'),
#   ('there', 'anyth'),
#   ('anyth', 'cheaper'),
#   ('cheaper', 'than'),
#   ('than', 'that'),
#   ('that', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'find'),
#   ('find', 'a'),
#   ('a', 'inexpens'),
#   ('inexpens', 'place'),
#   ('place', 'to'),
#   ('to', 'eat'),
#   ('eat', 'dinner'),
#   ('dinner', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'think'),
#   ('think', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'vegetarian'),
#   ('vegetarian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'also'),
#   ('also', 'um'),
#   ('um', 'in'),
#   ('in', 'addit'),
#   ('addit', 'to'),
#   ('to', 'vegetarian'),
#   ('vegetarian', 'i'),
#   ('i', 'would'),
#   ('would', 'also'),
#   ('also', 'like'),
#   ('like', 'to'),
#   ('to', 'tri'),
#   ('tri', 'to'),
#   ('to', 'see'),
#   ('see', 'if'),
#   ('if', 'i'),
#   ('i', 'can'),
#   ('can', 'find'),
#   ('find', 'some'),
#   ('some', 'mexican'),
#   ('mexican', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'find'),
#   ('find', 'some'),
#   ('some', 'place'),
#   ('place', 'that'),
#   ('that', 'fairli'),
#   ('fairli', 'close'),
#   ('close', 'to'),
#   ('to', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'you'),
#   ('you', 'give'),
#   ('give', 'me'),
#   ('me', 'some'),
#   ('some', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'manuel'),
#   ('manuel', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'find'),
#   ('find', 'a'),
#   ('a', 'realli'),
#   ('realli', 'nice'),
#   ('nice', 'place'),
#   ('place', 'to'),
#   ('to', 'eat'),
#   ('eat', 'lunch'),
#   ('lunch', 'next'),
#   ('next', 'wednesday'),
#   ('wednesday', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'either'),
#   ('either', 'french'),
#   ('french', 'food'),
#   ('food', 'california'),
#   ('california', 'food'),
#   ('food', 'or'),
#   ('or', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'have'),
#   ('have', 'a'),
#   ('a', 'car'),
#   ('car', 'so'),
#   ('so', 'the'),
#   ('the', 'distanc'),
#   ('distanc', 'is'),
#   ('is', 'not'),
#   ('not', 'import'),
#   ('import', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'you'),
#   ('you', 'give'),
#   ('give', 'me'),
#   ('me', 'some'),
#   ('some', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'skate'),
#   ('skate', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'you'),
#   ('you', 'show'),
#   ('show', 'me'),
#   ('me', 'those'),
#   ('those', 'the'),
#   ('the', 'list'),
#   ('list', 'of'),
#   ('of', 'restaur'),
#   ('restaur', 'again'),
#   ('again', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'see'),
#   ('see', 'some'),
#   ('some', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'augusta'),
#   ('augusta', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'i'),
#   ('i', 'see'),
#   ('see', 'the'),
#   ('the', 'origin'),
#   ('origin', 'list'),
#   ('list', 'again'),
#   ('again', '</sos>')],
#  [('<sos>', 'pleas'),
#   ('pleas', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'fourth'),
#   ('fourth', 'street'),
#   ('street', 'grill'),
#   ('grill', '</sos>')],
#  [('<sos>', 'alacart'),
#   ('alacart', 'addison'),
#   ('addison', 'annex'),
#   ('annex', 'amaru'),
#   ('amaru', 'arinel'),
#   ('arinel', 'pizza'),
#   ('pizza', 'augusta'),
#   ('augusta', '</sos>')],
#  [('<sos>', 'aycaramba'),
#   ('aycaramba', 'berkeley'),
#   ('berkeley', 'thai'),
#   ('thai', 'hous'),
#   ('hous', 'bett'),
#   ('bett', 'ocean'),
#   ('ocean', 'view'),
#   ('view', 'blondi'),
#   ('blondi', 'pizza'),
#   ('pizza', 'blue'),
#   ('blue', 'nile'),
#   ('nile', '</sos>')],
#  [('<sos>', 'bombay'),
#   ('bombay', 'cuisin'),
#   ('cuisin', 'brennan'),
#   ('brennan', 'brick'),
#   ('brick', 'hut'),
#   ('hut', 'cafe'),
#   ('cafe', 'britmari'),
#   ('britmari', 'cactu'),
#   ('cactu', 'taqueria'),
#   ('taqueria', '</sos>')],
#  [('<sos>', 'cafe'),
#   ('cafe', 'fanni'),
#   ('fanni', 'cafe'),
#   ('cafe', 'marmara'),
#   ('marmara', 'cafe'),
#   ('cafe', 'pastor'),
#   ('pastor', 'cafe'),
#   ('cafe', 'vin'),
#   ('vin', 'cafe'),
#   ('cafe', 'violeta'),
#   ('violeta', '</sos>')],
#  [('<sos>', 'caff'),
#   ('caff', 'giovanni'),
#   ('giovanni', 'caff'),
#   ('caff', 'venezia'),
#   ('venezia', 'cambodiana'),
#   ('cambodiana', 'casadeeva'),
#   ('casadeeva', 'casbah'),
#   ('casbah', '</sos>')],
#  [('<sos>', 'chaam'),
#   ('chaam', 'chezpaniss'),
#   ('chezpaniss', 'chezpaniss'),
#   ('chezpaniss', 'cafe'),
#   ('cafe', 'christoph'),
#   ('christoph', 'cafe'),
#   ('cafe', 'claremont'),
#   ('claremont', 'seafood'),
#   ('seafood', '</sos>')],
#  [('<sos>', 'coffe'),
#   ('coffe', 'renaiss'),
#   ('renaiss', 'continent'),
#   ('continent', 'garden'),
#   ('garden', 'daruma'),
#   ('daruma', 'teashop'),
#   ('teashop', 'elmwood'),
#   ('elmwood', 'pharmaci'),
#   ('pharmaci', 'everett'),
#   ('everett', 'and'),
#   ('and', 'jone'),
#   ('jone', 'barbecu'),
#   ('barbecu', '</sos>')],
#  [('<sos>', 'beep'),
#   ('beep', 'fat'),
#   ('fat', 'slice'),
#   ('slice', 'pizza'),
#   ('pizza', 'fat'),
#   ('fat', 'appl'),
#   ('appl', 'flint'),
#   ('flint', 'barbecu'),
#   ('barbecu', 'fourth'),
#   ('fourth', 'street'),
#   ('street', 'grill'),
#   ('grill', 'gerti'),
#   ('gerti', '</sos>')],
#  [('<sos>', 'gramma'),
#   ('gramma', 'inn'),
#   ('inn', 'guerrero'),
#   ('guerrero', 'homemad'),
#   ('homemad', 'cafe'),
#   ('cafe', 'hongfu'),
#   ('hongfu', 'hongkong'),
#   ('hongkong', 'villa'),
#   ('villa', '</sos>')],
#  [('<sos>', 'intern'),
#   ('intern', 'hous'),
#   ('hous', 'cafe'),
#   ('cafe', 'joshuya'),
#   ('joshuya', 'juan'),
#   ('juan', 'place'),
#   ('place', 'juic'),
#   ('juic', 'bar'),
#   ('bar', 'collect'),
#   ('collect', 'kip'),
#   ('kip', '</sos>')],
#  [('<sos>', 'kirala'),
#   ('kirala', 'la'),
#   ('la', 'mediterrane'),
#   ('mediterrane', 'laval'),
#   ('laval', 'lalim'),
#   ('lalim', 'lococo'),
#   ('lococo', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'lilli'),
#   ('lilli', 'long'),
#   ('long', 'life'),
#   ('life', 'vegi'),
#   ('vegi', 'hous'),
#   ('hous', 'maharani'),
#   ('maharani', 'manuel'),
#   ('manuel', 'mario'),
#   ('mario', 'la'),
#   ('la', 'fiesta'),
#   ('fiesta', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'meal'),
#   ('meal', 'ticket'),
#   ('ticket', 'metropol'),
#   ('metropol', 'nadin'),
#   ('nadin', 'omnivor'),
#   ('omnivor', 'orient'),
#   ('orient', 'food'),
#   ('food', 'to'),
#   ('to', 'go'),
#   ('go', '</sos>')],
#  [('<sos>', 'panini'),
#   ('panini', 'pasand'),
#   ('pasand', 'madra'),
#   ('madra', 'cuisin'),
#   ('cuisin', 'pepito'),
#   ('pepito', 'mexican'),
#   ('mexican', 'deli'),
#   ('deli', 'petrouchka'),
#   ('petrouchka', 'picant'),
#   ('picant', 'taqueria'),
#   ('taqueria', '</sos>')],
#  [('<sos>', 'plearn'),
#   ('plearn', 'thai'),
#   ('thai', 'cuisin'),
#   ('cuisin', 'rich'),
#   ('rich', 'potstick'),
#   ('potstick', 'ristorant'),
#   ('ristorant', 'venezia'),
#   ('venezia', 'sandwich'),
#   ('sandwich', 'agogo'),
#   ('agogo', 'saul'),
#   ('saul', 'deli'),
#   ('deli', '</sos>')],
#  [('<sos>', 'shinshin'),
#   ('shinshin', 'siam'),
#   ('siam', 'cuisin'),
#   ('cuisin', 'skate'),
#   ('skate', 'soup'),
#   ('soup', 'kitchen'),
#   ('kitchen', 'heik'),
#   ('heik', 'spenger'),
#   ('spenger', '</sos>')],
#  [('<sos>', 'stuf'),
#   ('stuf', 'inn'),
#   ('inn', 'sujatha'),
#   ('sujatha', 'sushisho'),
#   ('sushisho', 'taiwan'),
#   ('taiwan', 'restaur'),
#   ('restaur', 'thai'),
#   ('thai', 'barbecu'),
#   ('barbecu', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'the'),
#   ('the', 'milvia'),
#   ('milvia', 'the'),
#   ('the', 'swallow'),
#   ('swallow', 'top'),
#   ('top', 'dog'),
#   ('dog', 'tsingtao'),
#   ('tsingtao', 'vasiliki'),
#   ('vasiliki', '</sos>')],
#  [('<sos>', 'vegi'),
#   ('vegi', 'food'),
#   ('food', 'vietnam'),
#   ('vietnam', 'villag'),
#   ('villag', 'viva'),
#   ('viva', 'taqueria'),
#   ('taqueria', 'westsid'),
#   ('westsid', 'bakeri'),
#   ('bakeri', '</sos>')],
#  [('<sos>', 'won'),
#   ('won', 'thai'),
#   ('thai', 'cuisin'),
#   ('cuisin', 'yorkshir'),
#   ('yorkshir', 'fish'),
#   ('fish', 'and'),
#   ('and', 'chip'),
#   ('chip', 'zachari'),
#   ('zachari', 'chicago'),
#   ('chicago', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'chines'),
#   ('chines', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'thi'),
#   ('thi', 'afternoon'),
#   ('afternoon', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'spend'),
#   ('spend', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'seven'),
#   ('seven', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'travel'),
#   ('travel', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'three'),
#   ('three', 'block'),
#   ('block', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'monday'),
#   ('monday', 'afternoon'),
#   ('afternoon', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'fifti'),
#   ('fifti', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'travel'),
#   ('travel', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'twenti'),
#   ('twenti', 'block'),
#   ('block', '</sos>')],
#  [('<sos>', 'when'),
#   ('when', 'is'),
#   ('is', 'caff'),
#   ('caff', 'venezia'),
#   ('venezia', 'open'),
#   ('open', 'dure'),
#   ('dure', 'the'),
#   ('the', 'day'),
#   ('day', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'mexican'),
#   ('mexican', 'food'),
#   ('food', 'today'),
#   ('today', 'and'),
#   ('and', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'forti'),
#   ('forti', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'mexican'),
#   ('mexican', 'food'),
#   ('food', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'one'),
#   ('one', 'hundr'),
#   ('hundr', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'to'),
#   ('to', 'a'),
#   ('a', 'restaur'),
#   ('restaur', 'that'),
#   ('that', 'is'),
#   ('is', 'not'),
#   ('not', 'fast'),
#   ('fast', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'laughter'),
#   ('laughter', 'loudbreath'),
#   ('loudbreath', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'travel'),
#   ('travel', 'no'),
#   ('no', 'more'),
#   ('more', 'than'),
#   ('than', 'twenti'),
#   ('twenti', 'minut'),
#   ('minut', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'where'),
#   ('where', 'is'),
#   ('is', 'uh'),
#   ('uh', 'cactu'),
#   ('cactu', 'taqueria'),
#   ('taqueria', 'locat'),
#   ('locat', '</sos>')],
#  [('<sos>', 'pleas'),
#   ('pleas', 'show'),
#   ('show', 'the'),
#   ('the', 'list'),
#   ('list', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'i'),
#   ('i', 'wa'),
#   ('wa', 'think'),
#   ('think', 'about'),
#   ('about', 'go'),
#   ('go', 'out'),
#   ('out', 'for'),
#   ('for', 'some'),
#   ('some', 'french'),
#   ('french', 'food'),
#   ('food', 'tonight'),
#   ('tonight', '</sos>')],
#  [('<sos>', 'how'),
#   ('how', 'about'),
#   ('about', 'loudbreath'),
#   ('loudbreath', 'twelv'),
#   ('twelv', 'dollar'),
#   ('dollar', 'a'),
#   ('a', 'person'),
#   ('person', '</sos>')],
#  [('<sos>', 'ill'),
#   ('ill', 'tri'),
#   ('tri', 'to'),
#   ('to', 'get'),
#   ('get', 'a'),
#   ('a', 'car'),
#   ('car', 'so'),
#   ('so', 'it'),
#   ('it', 'shouldnt'),
#   ('shouldnt', 'matter'),
#   ('matter', 'loudbreath'),
#   ('loudbreath', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'whi'),
#   ('whi', 'dont'),
#   ('dont', 'you'),
#   ('you', 'make'),
#   ('make', 'that'),
#   ('that', 'up'),
#   ('up', 'to'),
#   ('to', 'sixteen'),
#   ('sixteen', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'can'),
#   ('can', 'i'),
#   ('i', 'have'),
#   ('have', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'um'),
#   ('um', 'lipsmack'),
#   ('lipsmack', 'metropol'),
#   ('metropol', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'you'),
#   ('you', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'asian'),
#   ('asian', 'food'),
#   ('food', 'in'),
#   ('in', 'berkeley'),
#   ('berkeley', '</sos>')],
#  [('<sos>', 'dinner'),
#   ('dinner', 'ani'),
#   ('ani', 'night'),
#   ('night', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'a'),
#   ('a', 'student'),
#   ('student', 'so'),
#   ('so', 'it'),
#   ('it', 'had'),
#   ('had', 'best'),
#   ('best', 'not'),
#   ('not', 'be'),
#   ('be', 'better'),
#   ('better', 'than'),
#   ('than', 'more'),
#   ('more', 'more'),
#   ('more', 'laughter'),
#   ('laughter', 'best'),
#   ('best', 'not'),
#   ('not', 'be'),
#   ('be', 'more'),
#   ('more', 'than'),
#   ('than', 'six'),
#   ('six', 'dollar'),
#   ('dollar', 'a'),
#   ('a', 'person'),
#   ('person', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'doesnt'),
#   ('doesnt', 'matter'),
#   ('matter', 'how'),
#   ('how', 'far'),
#   ('far', 'i'),
#   ('i', 'wan'),
#   ('wan', 'na'),
#   ('na', 'see'),
#   ('see', 'everyth'),
#   ('everyth', 'here'),
#   ('here', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'you'),
#   ('you', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'orient'),
#   ('orient', 'food'),
#   ('food', 'to'),
#   ('to', 'go'),
#   ('go', 'to'),
#   ('to', 'go'),
#   ('go', 'and'),
#   ('and', 'um'),
#   ('um', 'vietnam'),
#   ('vietnam', 'villag'),
#   ('villag', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'the'),
#   ('the', 'most'),
#   ('most', 'expens'),
#   ('expens', 'russian'),
#   ('russian', 'place'),
#   ('place', 'in'),
#   ('in', 'berkeley'),
#   ('berkeley', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'dinner'),
#   ('dinner', 'is'),
#   ('is', 'best'),
#   ('best', '</sos>')],
#  [('<sos>', 'it'),
#   ('it', 'can'),
#   ('can', 'be'),
#   ('be', 'anywher'),
#   ('anywher', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'alacart'),
#   ('alacart', 'addison'),
#   ('addison', 'annex'),
#   ('annex', 'amaru'),
#   ('amaru', 'arinel'),
#   ('arinel', 'pizza'),
#   ('pizza', 'augusta'),
#   ('augusta', '</sos>')],
#  [('<sos>', 'aycaramba'),
#   ('aycaramba', 'berkeley'),
#   ('berkeley', 'thai'),
#   ('thai', 'hous'),
#   ('hous', 'bett'),
#   ('bett', 'ocean'),
#   ('ocean', 'view'),
#   ('view', 'blondi'),
#   ('blondi', 'pizza'),
#   ('pizza', 'blue'),
#   ('blue', 'nile'),
#   ('nile', '</sos>')],
#  [('<sos>', 'brennan'),
#   ('brennan', 'brick'),
#   ('brick', 'hut'),
#   ('hut', 'cafe'),
#   ('cafe', 'britmari'),
#   ('britmari', 'cactu'),
#   ('cactu', 'taqueria'),
#   ('taqueria', 'cafe'),
#   ('cafe', 'fanni'),
#   ('fanni', '</sos>')],
#  [('<sos>', 'cafe'),
#   ('cafe', 'marmara'),
#   ('marmara', 'cafe'),
#   ('cafe', 'pastor'),
#   ('pastor', 'cafe'),
#   ('cafe', 'vin'),
#   ('vin', 'cafe'),
#   ('cafe', 'violeta'),
#   ('violeta', 'caff'),
#   ('caff', 'giovanni'),
#   ('giovanni', '</sos>')],
#  [('<sos>', 'caff'),
#   ('caff', 'venezia'),
#   ('venezia', 'cambodiana'),
#   ('cambodiana', 'casadeeva'),
#   ('casadeeva', 'casbah'),
#   ('casbah', 'chaam'),
#   ('chaam', '</sos>')],
#  [('<sos>', 'chezpaniss'),
#   ('chezpaniss', 'chezpaniss'),
#   ('chezpaniss', 'cafe'),
#   ('cafe', 'christoph'),
#   ('christoph', 'cafe'),
#   ('cafe', 'claremont'),
#   ('claremont', 'seafood'),
#   ('seafood', 'coffe'),
#   ('coffe', 'renaiss'),
#   ('renaiss', '</sos>')],
#  [('<sos>', 'continent'),
#   ('continent', 'garden'),
#   ('garden', 'daruma'),
#   ('daruma', 'teashop'),
#   ('teashop', 'elmwood'),
#   ('elmwood', 'pharmaci'),
#   ('pharmaci', 'everett'),
#   ('everett', 'and'),
#   ('and', 'jone'),
#   ('jone', 'barbecu'),
#   ('barbecu', 'fat'),
#   ('fat', 'slice'),
#   ('slice', 'pizza'),
#   ('pizza', '</sos>')],
#  [('<sos>', 'fat'),
#   ('fat', 'appl'),
#   ('appl', 'flint'),
#   ('flint', 'barbecu'),
#   ('barbecu', 'fourth'),
#   ('fourth', 'street'),
#   ('street', 'grill'),
#   ('grill', 'gerti'),
#   ('gerti', 'gramma'),
#   ('gramma', 'inn'),
#   ('inn', '</sos>')],
#  [('<sos>', 'guerrero'),
#   ('guerrero', 'homemad'),
#   ('homemad', 'cafe'),
#   ('cafe', 'hongfu'),
#   ('hongfu', 'hongkong'),
#   ('hongkong', 'villa'),
#   ('villa', 'intern'),
#   ('intern', 'hous'),
#   ('hous', 'cafe'),
#   ('cafe', '</sos>')],
#  [('<sos>', 'joshuya'),
#   ('joshuya', 'juan'),
#   ('juan', 'place'),
#   ('place', 'juic'),
#   ('juic', 'juic'),
#   ('juic', 'bar'),
#   ('bar', 'collect'),
#   ('collect', 'kip'),
#   ('kip', 'kirala'),
#   ('kirala', '</sos>')],
#  [('<sos>', 'la'),
#   ('la', 'mediterrane'),
#   ('mediterrane', 'laval'),
#   ('laval', 'lalim'),
#   ('lalim', 'lococo'),
#   ('lococo', 'restaur'),
#   ('restaur', 'lilli'),
#   ('lilli', '</sos>')],
#  [('<sos>', 'long'),
#   ('long', 'life'),
#   ('life', 'vegi'),
#   ('vegi', 'hous'),
#   ('hous', 'maharani'),
#   ('maharani', 'manuel'),
#   ('manuel', 'mario'),
#   ('mario', 'la'),
#   ('la', 'fiesta'),
#   ('fiesta', 'meal'),
#   ('meal', 'ticket'),
#   ('ticket', '</sos>')],
#  [('<sos>', 'metropol'),
#   ('metropol', 'nadin'),
#   ('nadin', 'omnivor'),
#   ('omnivor', 'orient'),
#   ('orient', 'food'),
#   ('food', 'to'),
#   ('to', 'go'),
#   ('go', 'panini'),
#   ('panini', '</sos>')],
#  [('<sos>', 'pasand'),
#   ('pasand', 'madra'),
#   ('madra', 'cuisin'),
#   ('cuisin', 'pepito'),
#   ('pepito', 'mexican'),
#   ('mexican', 'deli'),
#   ('deli', 'petrouchka'),
#   ('petrouchka', 'picant'),
#   ('picant', 'taqueria'),
#   ('taqueria', '</sos>')],
#  [('<sos>', 'plearn'),
#   ('plearn', 'thai'),
#   ('thai', 'cuisin'),
#   ('cuisin', 'rich'),
#   ('rich', 'potstick'),
#   ('potstick', 'ristorant'),
#   ('ristorant', 'venezia'),
#   ('venezia', 'sandwich'),
#   ('sandwich', 'agogo'),
#   ('agogo', '</sos>')],
#  [('<sos>', 'saul'),
#   ('saul', 'deli'),
#   ('deli', 'shinshin'),
#   ('shinshin', 'siam'),
#   ('siam', 'cuisin'),
#   ('cuisin', 'skate'),
#   ('skate', 'soup'),
#   ('soup', 'kitchen'),
#   ('kitchen', 'heik'),
#   ('heik', '</sos>')],
#  [('<sos>', 'spenger'),
#   ('spenger', 'stuf'),
#   ('stuf', 'inn'),
#   ('inn', 'sujatha'),
#   ('sujatha', 'sushisho'),
#   ('sushisho', 'taiwan'),
#   ('taiwan', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'thai'),
#   ('thai', 'barbecu'),
#   ('barbecu', 'the'),
#   ('the', 'milvia'),
#   ('milvia', 'the'),
#   ('the', 'swallow'),
#   ('swallow', 'top'),
#   ('top', 'dog'),
#   ('dog', 'tsingtao'),
#   ('tsingtao', '</sos>')],
#  [('<sos>', 'vasiliki'),
#   ('vasiliki', 'vegi'),
#   ('vegi', 'food'),
#   ('food', 'vietnam'),
#   ('vietnam', 'villag'),
#   ('villag', 'viva'),
#   ('viva', 'taqueria'),
#   ('taqueria', 'westsid'),
#   ('westsid', 'bakeri'),
#   ('bakeri', '</sos>')],
#  [('<sos>', 'won'),
#   ('won', 'thai'),
#   ('thai', 'cuisin'),
#   ('cuisin', 'yorkshir'),
#   ('yorkshir', 'fish'),
#   ('fish', 'and'),
#   ('and', 'chip'),
#   ('chip', 'beep'),
#   ('beep', 'zachari'),
#   ('zachari', 'chicago'),
#   ('chicago', 'yorkshir'),
#   ('yorkshir', 'fish'),
#   ('fish', 'and'),
#   ('and', 'chip'),
#   ('chip', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'lunch'),
#   ('lunch', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'dinner'),
#   ('dinner', 'on'),
#   ('on', 'sunday'),
#   ('sunday', 'even'),
#   ('even', '</sos>')],
#  [('<sos>', 'money'),
#   ('money', 'is'),
#   ('is', 'no'),
#   ('no', 'object'),
#   ('object', '</sos>')],
#  [('<sos>', 'sinc'),
#   ('sinc', 'i'),
#   ('i', 'have'),
#   ('have', 'a'),
#   ('a', 'car'),
#   ('car', 'travel'),
#   ('travel', 'distanc'),
#   ('distanc', 'is'),
#   ('is', 'not'),
#   ('not', 'import'),
#   ('import', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'cuban'),
#   ('cuban', 'food'),
#   ('food', 'not'),
#   ('not', 'to'),
#   ('to', 'spend'),
#   ('spend', 'more'),
#   ('more', 'than'),
#   ('than', 'twenti'),
#   ('twenti', 'five'),
#   ('five', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'russian'),
#   ('russian', 'food'),
#   ('food', 'and'),
#   ('and', 'not'),
#   ('not', 'spend'),
#   ('spend', 'more'),
#   ('more', 'than'),
#   ('than', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'thi'),
#   ('thi', 'late'),
#   ('late', 'afternoon'),
#   ('afternoon', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'not'),
#   ('not', 'to'),
#   ('to', 'travel'),
#   ('travel', 'more'),
#   ('more', 'than'),
#   ('than', 'a'),
#   ('a', 'mile'),
#   ('mile', 'away'),
#   ('away', 'from'),
#   ('from', 'here'),
#   ('here', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'some'),
#   ('some', 'russian'),
#   ('russian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'tell'), ('tell', 'me'), ('me', 'about'), ('about', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'someth'),
#   ('someth', 'about'),
#   ('about', 'petrouchka'),
#   ('petrouchka', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'have'),
#   ('have', 'some'),
#   ('some', 'uh'),
#   ('uh', 'fish'),
#   ('fish', 'food'),
#   ('food', 'for'),
#   ('for', 'dinner'),
#   ('dinner', 'and'),
#   ('and', 'um'),
#   ('um', 'im'),
#   ('im', 'not'),
#   ('not', 'realli'),
#   ('realli', 'sure'),
#   ('sure', 'what'),
#   ('what', 'type'),
#   ('type', 'of'),
#   ('of', 'restaur'),
#   ('restaur', 'it'),
#   ('it', 'should'),
#   ('should', 'be'),
#   ('be', 'whether'),
#   ('whether', 'or'),
#   ('or', '</sos>')],
#  [('<sos>', 'like'),
#   ('like', 'to'),
#   ('to', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'um'),
#   ('um', 'eat'),
#   ('eat', 'tonight'),
#   ('tonight', 'um'),
#   ('um', 'at'),
#   ('at', 'seven'),
#   ('seven', 'oclock'),
#   ('oclock', 'pm'),
#   ('pm', 'approxim'),
#   ('approxim', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'someth'),
#   ('someth', 'in'),
#   ('in', 'the'),
#   ('the', 'medium'),
#   ('medium', 'rang'),
#   ('rang', 'let'),
#   ('let', 'say'),
#   ('say', 'about'),
#   ('about', 'twenti'),
#   ('twenti', 'twenti'),
#   ('twenti', 'five'),
#   ('five', 'dollar'),
#   ('dollar', 'per'),
#   ('per', 'person'),
#   ('person', '</sos>')],
#  [('<sos>', 'oh'),
#   ('oh', 'um'),
#   ('um', 'how'),
#   ('how', 'far'),
#   ('far', 'from'),
#   ('from', 'icsi'),
#   ('icsi', 'um'),
#   ('um', 'lipsmack'),
#   ('lipsmack', 'somewher'),
#   ('somewher', 'either'),
#   ('either', 'in'),
#   ('in', 'walk'),
#   ('walk', 'distanc'),
#   ('distanc', 'or'),
#   ('or', 'where'),
#   ('where', 'i'),
#   ('i', 'can'),
#   ('can', 'take'),
#   ('take', 'uh'),
#   ('uh', '</sos>')],
#  [('<sos>', 'could'),
#   ('could', 'you'),
#   ('you', 'pleas'),
#   ('pleas', 'give'),
#   ('give', 'us'),
#   ('us', 'some'),
#   ('some', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'gerti'),
#   ('gerti', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'i'),
#   ('i', 'would'),
#   ('would', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'for'),
#   ('for', 'lunch'),
#   ('lunch', 'uh'),
#   ('uh', 'to'),
#   ('to', 'some'),
#   ('some', 'mexican'),
#   ('mexican', 'place'),
#   ('place', 'loudbreath'),
#   ('loudbreath', '</sos>')],
#  [('<sos>', 'well'),
#   ('well', 'uh'),
#   ('uh', 'loudbreath'),
#   ('loudbreath', 'not'),
#   ('not', 'veri'),
#   ('veri', 'much'),
#   ('much', 'loudbreath'),
#   ('loudbreath', 'someth'),
#   ('someth', 'in'),
#   ('in', 'the'),
#   ('the', 'up'),
#   ('up', 'to'),
#   ('to', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'rang'),
#   ('rang', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'actual'),
#   ('actual', 'i'),
#   ('i', 'have'),
#   ('have', 'a'),
#   ('a', 'car'),
#   ('car', 'avail'),
#   ('avail', 'now'),
#   ('now', 'so'),
#   ('so', 'my'),
#   ('my', 'friend'),
#   ('friend', 'can'),
#   ('can', 'take'),
#   ('take', 'me'),
#   ('me', 'to'),
#   ('to', 'um'),
#   ('um', 'anywher'),
#   ('anywher', 'within'),
#   ('within', 'the'),
#   ('the', 'east'),
#   ('east', 'bay'),
#   ('bay', 'area'),
#   ('area', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'havent'),
#   ('havent', 'yet'),
#   ('yet', 'tri'),
#   ('tri', 'cactu'),
#   ('cactu', 'taqueria'),
#   ('taqueria', 'so'),
#   ('so', 'could'),
#   ('could', 'you'),
#   ('you', 'pleas'),
#   ('pleas', 'give'),
#   ('give', 'me'),
#   ('me', 'um'),
#   ('um', 'some'),
#   ('some', 'addit'),
#   ('addit', 'inform'),
#   ('inform', 'on'),
#   ('on', 'it'),
#   ('it', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'thank'),
#   ('thank', 'you'),
#   ('you', 'for'),
#   ('for', 'thi'),
#   ('thi', 'inform'),
#   ('inform', 'but'),
#   ('but', 'could'),
#   ('could', 'you'),
#   ('you', 'pleas'),
#   ('pleas', 'tell'),
#   ('tell', 'me'),
#   ('me', 'if'),
#   ('if', 'they'),
#   ('they', 'uh'),
#   ('uh', 'serv'),
#   ('serv', 'alcohol'),
#   ('alcohol', 'or'),
#   ('or', 'not'),
#   ('not', '</sos>')],
#  [('<sos>', 'could'),
#   ('could', 'i'),
#   ('i', 'pleas'),
#   ('pleas', 'see'),
#   ('see', 'a'),
#   ('a', 'list'),
#   ('list', 'of'),
#   ('of', 'um'),
#   ('um', 'mexican'),
#   ('mexican', 'restaur'),
#   ('restaur', 'that'),
#   ('that', 'i'),
#   ('i', 'ask'),
#   ('ask', 'for'),
#   ('for', 'befor'),
#   ('befor', '</sos>')],
#  [('<sos>', 'could'),
#   ('could', 'you'),
#   ('you', 'possibl'),
#   ('possibl', 'recommend'),
#   ('recommend', 'ani'),
#   ('ani', 'place'),
#   ('place', 'yourself'),
#   ('yourself', '</sos>')],
#  [('<sos>', 'thank'),
#   ('thank', 'you'),
#   ('you', 'veri'),
#   ('veri', 'much'),
#   ('much', 'and'),
#   ('and', 'goodby'),
#   ('goodby', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'lipsmack'),
#   ('lipsmack', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'a'),
#   ('a', 'thai'),
#   ('thai', 'restaur'),
#   ('restaur', 'that'),
#   ('that', 'is'),
#   ('is', 'not'),
#   ('not', 'too'),
#   ('too', 'expens'),
#   ('expens', 'and'),
#   ('and', 'is'),
#   ('is', 'on'),
#   ('on', 'south'),
#   ('south', 'side'),
#   ('side', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'lipsmack'),
#   ('lipsmack', 'um'),
#   ('um', 'for'),
#   ('for', 'dinner'),
#   ('dinner', 'on'),
#   ('on', 'the'),
#   ('the', 'weekend'),
#   ('weekend', 'that'),
#   ('that', 'doesnt'),
#   ('doesnt', 'requir'),
#   ('requir', 'reserv'),
#   ('reserv', 'laughter'),
#   ('laughter', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'id'),
#   ('id', 'like'),
#   ('like', 'some'),
#   ('some', 'inform'),
#   ('inform', 'on'),
#   ('on', 'chaam'),
#   ('chaam', 'laughter'),
#   ('laughter', 'thai'),
#   ('thai', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'a'),
#   ('a', 'restaur'),
#   ('restaur', 'for'),
#   ('for', 'my'),
#   ('my', 'parent'),
#   ('parent', 'when'),
#   ('when', 'they'),
#   ('they', 'come'),
#   ('come', 'into'),
#   ('into', 'town'),
#   ('town', 'um'),
#   ('um', 'lipsmack'),
#   ('lipsmack', 'italian'),
#   ('italian', 'food'),
#   ('food', 'um'),
#   ('um', 'dressi'),
#   ('dressi', 'casual'),
#   ('casual', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'loudbreath'),
#   ('loudbreath', 'would'),
#   ('would', 'be'),
#   ('be', 'for'),
#   ('for', 'dinner'),
#   ('dinner', 'on'),
#   ('on', 'a'),
#   ('a', 'friday'),
#   ('friday', 'or'),
#   ('or', 'saturday'),
#   ('saturday', 'even'),
#   ('even', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'loudbreath'),
#   ('loudbreath', 'um'),
#   ('um', 'my'),
#   ('my', 'parent'),
#   ('parent', 'would'),
#   ('would', 'be'),
#   ('be', 'will'),
#   ('will', 'to'),
#   ('to', 'spend'),
#   ('spend', 'fifteen'),
#   ('fifteen', 'to'),
#   ('to', 'twenti'),
#   ('twenti', 'five'),
#   ('five', 'dollar'),
#   ('dollar', 'on'),
#   ('on', 'entre'),
#   ('entre', 'um'),
#   ('um', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'loudbreath'),
#   ('loudbreath', 'um'),
#   ('um', 'we'),
#   ('we', 'have'),
#   ('have', 'an'),
#   ('an', 'automobil'),
#   ('automobil', 'so'),
#   ('so', 'we'),
#   ('we', 'can'),
#   ('can', 'go'),
#   ('go', 'anywher'),
#   ('anywher', 'within'),
#   ('within', 'the'),
#   ('the', 'berkeley'),
#   ('berkeley', 'area'),
#   ('area', 'doesnt'),
#   ('doesnt', 'matter'),
#   ('matter', 'how'),
#   ('how', 'far'),
#   ('far', 'and'),
#   ('and', 'a'),
#   ('a', 'resta'),
#   ('resta', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'inform'),
#   ('inform', 'on'),
#   ('on', 'ristorant'),
#   ('ristorant', 'venezia'),
#   ('venezia', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'lipsmack'),
#   ('lipsmack', 'w'),
#   ('w', 'laughter'),
#   ('laughter', 'loudbreath'),
#   ('loudbreath', 'show'),
#   ('show', 'me'),
#   ('me', 'the'),
#   ('the', 'list'),
#   ('list', 'loudbreath'),
#   ('loudbreath', 'well'),
#   ('well', 'no'),
#   ('no', 'what'),
#   ('what', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'do'),
#   ('do', 'wa'),
#   ('wa', 'um'),
#   ('um', '</sos>')],
#  [('<sos>', 'start'),
#   ('start', 'over'),
#   ('over', 'laughter'),
#   ('laughter', 'loudbreath'),
#   ('loudbreath', 'show'),
#   ('show', 'me'),
#   ('me', 'the'),
#   ('the', 'list'),
#   ('list', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'the'),
#   ('the', 'music'),
#   ('music', 'offer'),
#   ('offer', 'cafe'),
#   ('cafe', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'cafe'),
#   ('cafe', 'milano'),
#   ('milano', '</sos>')],
#  [('<sos>', 'start'),
#   ('start', 'over'),
#   ('over', 'laughter'),
#   ('laughter', 'loudbreath'),
#   ('loudbreath', 'um'),
#   ('um', 'show'),
#   ('show', 'me'),
#   ('me', 'the'),
#   ('the', 'list'),
#   ('list', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'a'),
#   ('a', 'greek'),
#   ('greek', 'restaur'),
#   ('restaur', 'um'),
#   ('um', 'casual'),
#   ('casual', 'for'),
#   ('for', 'the'),
#   ('the', 'weekend'),
#   ('weekend', 'even'),
#   ('even', 'um'),
#   ('um', 'that'),
#   ('that', 'between'),
#   ('between', 'the'),
#   ('the', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'i'),
#   ('i', 'dont'),
#   ('dont', 'want'),
#   ('want', 'to'),
#   ('to', 'travel'),
#   ('travel', 'ani'),
#   ('ani', 'further'),
#   ('further', 'than'),
#   ('than', 'ten'),
#   ('ten', 'minut'),
#   ('minut', 'from'),
#   ('from', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'inform'),
#   ('inform', 'about'),
#   ('about', 'vasiliki'),
#   ('vasiliki', '</sos>')],
#  [('<sos>', 'loudbreath'),
#   ('loudbreath', 'do'),
#   ('do', 'you'),
#   ('you', 'need'),
#   ('need', 'reserv'),
#   ('reserv', 'for'),
#   ('for', 'thi'),
#   ('thi', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'loudbreath'),
#   ('loudbreath', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'a'),
#   ('a', 'fun'),
#   ('fun', 'um'),
#   ('um', 'mostli'),
#   ('mostli', 'colleg'),
#   ('colleg', 'crowd'),
#   ('crowd', 'loudbreath'),
#   ('loudbreath', 'mexican'),
#   ('mexican', 'food'),
#   ('food', 'restaur'),
#   ('restaur', 'that'),
#   ('that', 'cheap'),
#   ('cheap', '</sos>')],
#  [('<sos>', 'lipsmack'),
#   ('lipsmack', 'it'),
#   ('it', 'would'),
#   ('would', 'be'),
#   ('be', 'for'),
#   ('for', 'the'),
#   ('the', 'weekend'),
#   ('weekend', 'um'),
#   ('um', 'i'),
#   ('i', 'would'),
#   ('would', 'prefer'),
#   ('prefer', 'it'),
#   ('it', 'to'),
#   ('to', 'be'),
#   ('be', 'no'),
#   ('no', 'more'),
#   ('more', 'that'),
#   ('that', 'ten'),
#   ('ten', 'minut'),
#   ('minut', 'away'),
#   ('away', 'from'),
#   ('from', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'beep'),
#   ('beep', 'lipsmack'),
#   ('lipsmack', 'loudbreath'),
#   ('loudbreath', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'manuel'),
#   ('manuel', '</sos>')],
#  [('<sos>', 'beep'), ('beep', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'oh'),
#   ('oh', 'you'),
#   ('you', 'dont'),
#   ('dont', 'have'),
#   ('have', 'anyth'),
#   ('anyth', 'about'),
#   ('about', 'locat'),
#   ('locat', 'like'),
#   ('like', 'hearst'),
#   ('hearst', 'avenu'),
#   ('avenu', 'finish'),
#   ('finish', 'laughter'),
#   ('laughter', 'loudbreath'),
#   ('loudbreath', '</sos>')],
#  [('<sos>', 'comput'),
#   ('comput', 'alright'),
#   ('alright', 'im'),
#   ('im', 'realli'),
#   ('realli', 'hungri'),
#   ('hungri', 'today'),
#   ('today', 'for'),
#   ('for', 'some'),
#   ('some', 'thai'),
#   ('thai', 'food'),
#   ('food', 'loudbreath'),
#   ('loudbreath', 'and'),
#   ('and', 'uh'),
#   ('uh', 'ive'),
#   ('ive', 'got'),
#   ('got', 'about'),
#   ('about', 'three'),
#   ('three', 'and'),
#   ('and', 'half'),
#   ('half', 'dollar'),
#   ('dollar', 'to'),
#   ('to', 'spend'),
#   ('spend', '</sos>')],
#  [('<sos>', 'less'),
#   ('less', 'than'),
#   ('than', 'ten'),
#   ('ten', 'minut'),
#   ('minut', 'distanc'),
#   ('distanc', 'in'),
#   ('in', 'term'),
#   ('term', 'of'),
#   ('of', 'time'),
#   ('time', 'too'),
#   ('too', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'have'),
#   ('have', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'less'),
#   ('less', 'than'),
#   ('than', 'six'),
#   ('six', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'okay'),
#   ('okay', 'i'),
#   ('i', 'can'),
#   ('can', 'spring'),
#   ('spring', 'for'),
#   ('for', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'nakapan'),
#   ('nakapan', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'plearn'),
#   ('plearn', 'thai'),
#   ('thai', 'cuisin'),
#   ('cuisin', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'eat'),
#   ('eat', 'mexican'),
#   ('mexican', 'food'),
#   ('food', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'onli'),
#   ('onli', 'have'),
#   ('have', 'five'),
#   ('five', 'dollar'),
#   ('dollar', 'and'),
#   ('and', 'i'),
#   ('i', 'dont'),
#   ('dont', 'have'),
#   ('have', 'a'),
#   ('a', 'lot'),
#   ('lot', 'of'),
#   ('of', 'time'),
#   ('time', 'so'),
#   ('so', 'less'),
#   ('less', 'than'),
#   ('than', 'five'),
#   ('five', 'minut'),
#   ('minut', '</sos>')],
#  [('<sos>', 'show'),
#   ('show', 'me'),
#   ('me', 'all'),
#   ('all', 'the'),
#   ('the', 'mexican'),
#   ('mexican', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'what'),
#   ('what', 'good'),
#   ('good', 'at'),
#   ('at', 'cactu'),
#   ('cactu', 'taqueria'),
#   ('taqueria', '</sos>')],
#  [('<sos>', 'show'),
#   ('show', 'me'),
#   ('me', 'all'),
#   ('all', 'the'),
#   ('the', 'barbecu'),
#   ('barbecu', 'place'),
#   ('place', 'within'),
#   ('within', 'fifteen'),
#   ('fifteen', 'minut'),
#   ('minut', 'of'),
#   ('of', 'ickse'),
#   ('ickse', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'interest'),
#   ('interest', 'in'),
#   ('in', 'lunch'),
#   ('lunch', 'and'),
#   ('and', 'dinner'),
#   ('dinner', '</sos>')],
#  [('<sos>', 'up'),
#   ('up', 'to'),
#   ('to', 'fifteen'),
#   ('fifteen', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'show'),
#   ('show', 'me'),
#   ('me', 'all'),
#   ('all', 'the'),
#   ('the', 'barbecu'),
#   ('barbecu', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'show'),
#   ('show', 'me'),
#   ('me', 'all'),
#   ('all', 'the'),
#   ('the', 'mexican'),
#   ('mexican', 'restaur'),
#   ('restaur', 'within'),
#   ('within', 'fifteen'),
#   ('fifteen', 'minut'),
#   ('minut', 'drive'),
#   ('drive', 'of'),
#   ('of', 'ickse'),
#   ('ickse', '</sos>')],
#  [('<sos>', 'show'),
#   ('show', 'me'),
#   ('me', 'the'),
#   ('the', 'santaf'),
#   ('santaf', 'bar'),
#   ('bar', 'and'),
#   ('and', 'grill'),
#   ('grill', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'an'),
#   ('an', 'indian'),
#   ('indian', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'a'),
#   ('a', 'um'),
#   ('um', 'loudbreath'),
#   ('loudbreath', 'um'),
#   ('um', 'an'),
#   ('an', 'even'),
#   ('even', 'buffet'),
#   ('buffet', 'friday'),
#   ('friday', 'or'),
#   ('or', 'saturday'),
#   ('saturday', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'about'),
#   ('about', 'fifteen'),
#   ('fifteen', 'dollar'),
#   ('dollar', 'per'),
#   ('per', 'person'),
#   ('person', '</sos>')],
#  [('<sos>', 'within'),
#   ('within', 'three'),
#   ('three', 'mile'),
#   ('mile', 'of'),
#   ('of', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'doe'),
#   ('doe', 'maharani'),
#   ('maharani', 'serv'),
#   ('serv', 'vegetarian'),
#   ('vegetarian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'uh'),
#   ('uh', 'comput'),
#   ('comput', 'um'),
#   ('um', 'uh'),
#   ('uh', 'are'),
#   ('are', 'there'),
#   ('there', 'ani'),
#   ('ani', 'fanci'),
#   ('fanci', 'restaur'),
#   ('restaur', 'in'),
#   ('in', 'berkeley'),
#   ('berkeley', '</sos>')],
#  [('<sos>', 'with'),
#   ('with', 'california'),
#   ('california', 'cuisin'),
#   ('cuisin', '</sos>')],
#  [('<sos>', 'um'), ('um', 'dinner'), ('dinner', 'time'), ('time', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'lipsmack'),
#   ('lipsmack', 'within'),
#   ('within', 'an'),
#   ('an', 'hour'),
#   ('hour', 'of'),
#   ('of', 'ickse'),
#   ('ickse', 'nois'),
#   ('nois', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'more'),
#   ('more', 'about'),
#   ('about', 'christoph'),
#   ('christoph', 'cafe'),
#   ('cafe', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'show'),
#   ('show', 'me'),
#   ('me', 'the'),
#   ('the', 'list'),
#   ('list', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'do'),
#   ('do', 'ani'),
#   ('ani', 'of'),
#   ('of', 'the'),
#   ('the', 'restaur'),
#   ('restaur', 'on'),
#   ('on', 'the'),
#   ('the', 'list'),
#   ('list', 'take'),
#   ('take', 'credit'),
#   ('credit', 'card'),
#   ('card', 'unintellig'),
#   ('unintellig', '</sos>')],
#  [('<sos>', 'which'),
#   ('which', 'restaur'),
#   ('restaur', 'on'),
#   ('on', 'the'),
#   ('the', 'list'),
#   ('list', 'are'),
#   ('are', 'open'),
#   ('open', 'on'),
#   ('on', 'sunday'),
#   ('sunday', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'uh'),
#   ('uh', 'find'),
#   ('find', 'me'),
#   ('me', 'restaur'),
#   ('restaur', 'that'),
#   ('that', 'are'),
#   ('are', 'on'),
#   ('on', 'sanpablo'),
#   ('sanpablo', 'avenu'),
#   ('avenu', '</sos>')],
#  [('<sos>', 'um'),
#   ('um', 'are'),
#   ('are', 'there'),
#   ('there', 'ani'),
# ...
#   ('wan', 'na'),
#   ('na', 'burrito'),
#   ('burrito', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'someth'),
#   ('someth', 'cheap'),
#   ('cheap', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'dont'),
#   ('dont', 'have'),
#   ('have', 'a'),
#   ('a', 'car'),
#   ('car', '</sos>')],
#  [('<sos>', 'thi'),
#   ('thi', 'place'),
#   ('place', 'should'),
#   ('should', 'be'),
#   ('be', 'in'),
#   ('in', 'walk'),
#   ('walk', 'distanc'),
#   ('distanc', '</sos>')],
#  [('<sos>', 'are'),
#   ('are', 'the'),
#   ('the', 'waitress'),
#   ('waitress', 'pretti'),
#   ('pretti', 'at'),
#   ('at', 'aycaramba'),
#   ('aycaramba', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'about'),
#   ('about', 'the'),
#   ('the', 'other'),
#   ('other', 'one'),
#   ('one', '</sos>')],
#  [('<sos>', 'aucoquelet'), ('aucoquelet', '</sos>')],
#  [('<sos>', 'my'),
#   ('my', 'friend'),
#   ('friend', 'here'),
#   ('here', 'like'),
#   ('like', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'howbout'),
#   ('howbout', 'thai'),
#   ('thai', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'will'),
#   ('will', 'to'),
#   ('to', 'pay'),
#   ('pay', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', 'or'),
#   ('or', 'so'),
#   ('so', '</sos>')],
#  [('<sos>', 'tell'),
#   ('tell', 'me'),
#   ('me', 'everyth'),
#   ('everyth', 'you'),
#   ('you', 'know'),
#   ('know', 'about'),
#   ('about', 'thai'),
#   ('thai', 'barbecu'),
#   ('barbecu', '</sos>')],
#  [('<sos>', 'nois'),
#   ('nois', 'nina'),
#   ('nina', 'think'),
#   ('think', 'your'),
#   ('your', 'total'),
#   ('total', 'cool'),
#   ('cool', '</sos>')],
#  [('<sos>', 'im'), ('im', 'into'), ('into', 'chines'), ('chines', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'look'),
#   ('look', 'for'),
#   ('for', 'some'),
#   ('some', 'place'),
#   ('place', 'to'),
#   ('to', 'take'),
#   ('take', 'somebodi'),
#   ('somebodi', 'picki'),
#   ('picki', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wan'),
#   ('wan', 'na'),
#   ('na', 'eat'),
#   ('eat', 'realli'),
#   ('realli', 'good'),
#   ('good', 'food'),
#   ('food', 'i'),
#   ('i', 'dont'),
#   ('dont', 'care'),
#   ('care', 'how'),
#   ('how', 'much'),
#   ('much', 'it'),
#   ('it', 'cost'),
#   ('cost', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'veri'),
#   ('veri', 'high'),
#   ('high', 'qualiti'),
#   ('qualiti', 'food'),
#   ('food', 'someth'),
#   ('someth', 'realli'),
#   ('realli', 'tasti'),
#   ('tasti', '</sos>')],
#  [('<sos>', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'some'),
#   ('some', 'place'),
#   ('place', 'expens'),
#   ('expens', '</sos>')],
#  [('<sos>', 'hi'),
#   ('hi', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'get'),
#   ('get', 'anyth'),
#   ('anyth', 'except'),
#   ('except', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'okay'),
#   ('okay', 'look'),
#   ('look', 'i'),
#   ('i', 'wan'),
#   ('wan', 'na'),
#   ('na', 'eat'),
#   ('eat', 'dinner'),
#   ('dinner', 'tonight'),
#   ('tonight', 'and'),
#   ('and', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'spend'),
#   ('spend', 'thirti'),
#   ('thirti', 'dollar'),
#   ('dollar', 'okay'),
#   ('okay', '</sos>')],
#  [('<sos>', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'up'),
#   ('up', 'to'),
#   ('to', 'thirti'),
#   ('thirti', 'dollar'),
#   ('dollar', 'and'),
#   ('and', 'im'),
#   ('im', 'a'),
#   ('a', 'vegetarian'),
#   ('vegetarian', '</sos>')],
#  [('<sos>', 'how'),
#   ('how', 'about'),
#   ('about', 'someth'),
#   ('someth', 'farther'),
#   ('farther', 'away'),
#   ('away', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'drive'),
#   ('drive', 'there'),
#   ('there', 'in'),
#   ('in', 'a'),
#   ('a', 'car'),
#   ('car', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'dont'),
#   ('dont', 'care'),
#   ('care', 'whether'),
#   ('whether', 'it'),
#   ('it', 'close'),
#   ('close', 'or'),
#   ('or', 'not'),
#   ('not', '</sos>')],
#  [('<sos>', 'is'),
#   ('is', 'there'),
#   ('there', 'ani'),
#   ('ani', 'place'),
#   ('place', 'around'),
#   ('around', 'here'),
#   ('here', 'with'),
#   ('with', 'entertain'),
#   ('entertain', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'some'),
#   ('some', 'place'),
#   ('place', 'with'),
#   ('with', 'a'),
#   ('a', 'bar'),
#   ('bar', '</sos>')],
#  [('<sos>', 'is'),
#   ('is', 'there'),
#   ('there', 'ani'),
#   ('ani', 'place'),
#   ('place', 'that'),
#   ('that', 'ha'),
#   ('ha', 'a'),
#   ('a', 'full'),
#   ('full', 'bar'),
#   ('bar', 'and'),
#   ('and', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'just'),
#   ('just', 'wan'),
#   ('wan', 'na'),
#   ('na', 'get'),
#   ('get', 'like'),
#   ('like', 'drink'),
#   ('drink', 'and'),
#   ('and', 'snack'),
#   ('snack', 'although'),
#   ('although', 'my'),
#   ('my', 'friend'),
#   ('friend', 'here'),
#   ('here', 'want'),
#   ('want', 'a'),
#   ('a', 'sandwich'),
#   ('sandwich', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'sandwich'),
#   ('sandwich', 'and'),
#   ('and', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'is'),
#   ('is', 'there'),
#   ('there', 'ani'),
#   ('ani', 'place'),
#   ('place', 'for'),
#   ('for', 'dinner'),
#   ('dinner', 'that'),
#   ('that', 'isnt'),
#   ('isnt', 'close'),
#   ('close', 'on'),
#   ('on', 'monday'),
#   ('monday', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'pay'),
#   ('pay', 'a'),
#   ('a', 'lot'),
#   ('lot', '</sos>')],
#  [('<sos>', 'ill'),
#   ('ill', 'spend'),
#   ('spend', 'ani'),
#   ('ani', 'amount'),
#   ('amount', 'of'),
#   ('of', 'money'),
#   ('money', 'for'),
#   ('for', 'good'),
#   ('good', 'vietnames'),
#   ('vietnames', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'could'),
#   ('could', 'go'),
#   ('go', 'veri'),
#   ('veri', 'far'),
#   ('far', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'have'),
#   ('have', 'to'),
#   ('to', 'be'),
#   ('be', 'on'),
#   ('on', 'the'),
#   ('the', 'road'),
#   ('road', 'by'),
#   ('by', 'eight'),
#   ('eight', 'am'),
#   ('am', '</sos>')],
#  [('<sos>', 's'), ('s', 'pleas'), ('pleas', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'get'),
#   ('get', 'breakfast'),
#   ('breakfast', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wan'),
#   ('wan', 'na'),
#   ('na', 'eat'),
#   ('eat', 'today'),
#   ('today', '</sos>')],
#  [('<sos>', 'can'),
#   ('can', 'i'),
#   ('i', 'go'),
#   ('go', 'to'),
#   ('to', 'just'),
#   ('just', 'like'),
#   ('like', 'a'),
#   ('a', 'normal'),
#   ('normal', 'american'),
#   ('american', 'restaur'),
#   ('restaur', 'mayb'),
#   ('mayb', 'a'),
#   ('a', 'diner'),
#   ('diner', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'spend'),
#   ('spend', 'i'),
#   ('i', 'dont'),
#   ('dont', 'know'),
#   ('know', 'under'),
#   ('under', 'ten'),
#   ('ten', 'buck'),
#   ('buck', 'someth'),
#   ('someth', 'like'),
#   ('like', 'that'),
#   ('that', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'could'),
#   ('could', 'spend'),
#   ('spend', 'under'),
#   ('under', 'ten'),
#   ('ten', 'buck'),
#   ('buck', '</sos>')],
#  [('<sos>', 'okay'),
#   ('okay', 'i'),
#   ('i', 'could'),
#   ('could', 'spend'),
#   ('spend', 'under'),
#   ('under', 'ten'),
#   ('ten', 'dollar'),
#   ('dollar', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'be'),
#   ('be', 'will'),
#   ('will', 'to'),
#   ('to', 'shell'),
#   ('shell', 'out'),
#   ('out', 'anyth'),
#   ('anyth', 'up'),
#   ('up', 'to'),
#   ('to', 'about'),
#   ('about', 'uh'),
#   ('uh', 'ten'),
#   ('ten', 'semolian'),
#   ('semolian', 'laughter'),
#   ('laughter', 'nois'),
#   ('nois', '</sos>')],
#  [('<sos>', 'so'),
#   ('so', 'which'),
#   ('which', 'one'),
#   ('one', 'of'),
#   ('of', 'these'),
#   ('these', 'place'),
#   ('place', 'is'),
#   ('is', 'realli'),
#   ('realli', 'good'),
#   ('good', '</sos>')],
#  [('<sos>', 'howbout'),
#   ('howbout', 'an'),
#   ('an', 'american'),
#   ('american', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'to'),
#   ('to', 'go'),
#   ('go', 'for'),
#   ('for', 'dinner'),
#   ('dinner', 'to'),
#   ('to', 'kind'),
#   ('kind', 'of'),
#   ('of', 'upscal'),
#   ('upscal', 'yuppi'),
#   ('yuppi', 'california'),
#   ('california', 'cuisin'),
#   ('cuisin', 'kind'),
#   ('kind', 'of'),
#   ('of', 'place'),
#   ('place', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'a'),
#   ('a', 'california'),
#   ('california', 'cuisin'),
#   ('cuisin', 'restaur'),
#   ('restaur', 'pleas'),
#   ('pleas', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'dinner'),
#   ('dinner', 'on'),
#   ('on', 'friday'),
#   ('friday', 'night'),
#   ('night', 'and'),
#   ('and', 'no'),
#   ('no', 'reserv'),
#   ('reserv', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'could'),
#   ('could', 'take'),
#   ('take', 'a'),
#   ('a', 'date'),
#   ('date', '</sos>')],
#  [('<sos>', 'i'), ('i', 'dont'), ('dont', 'care'), ('care', '</sos>')],
#  [('<sos>', 'i'), ('i', 'dont'), ('dont', 'care'), ('care', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'dont'),
#   ('dont', 'care'),
#   ('care', 'about'),
#   ('about', 'that'),
#   ('that', 'either'),
#   ('either', '</sos>')],
#  [('<sos>', 'so'),
#   ('so', 'which'),
#   ('which', 'is'),
#   ('is', 'the'),
#   ('the', 'cheapest'),
#   ('cheapest', '</sos>')],
#  [('<sos>', 'start'), ('start', 'over'), ('over', '</sos>')],
#  [('<sos>', 'id'),
#   ('id', 'like'),
#   ('like', 'a'),
#   ('a', 'veri'),
#   ('veri', 'authent'),
#   ('authent', 'mexican'),
#   ('mexican', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'like'),
#   ('like', 'just'),
#   ('just', 'an'),
#   ('an', 'authent'),
#   ('authent', 'mexican'),
#   ('mexican', 'restaur'),
#   ('restaur', 'with'),
#   ('with', 'burrito'),
#   ('burrito', 'and'),
#   ('and', 'mayb'),
#   ('mayb', 'no'),
#   ('no', 'seat'),
#   ('seat', '</sos>')],
#  [('<sos>', 'is'),
#   ('is', 'there'),
#   ('there', 'a'),
#   ('a', 'take'),
#   ('take', 'out'),
#   ('out', 'place'),
#   ('place', '</sos>')],
#  [('<sos>', 'whi'),
#   ('whi', 'wont'),
#   ('wont', 'it'),
#   ('it', 'stop'),
#   ('stop', '</sos>')],
#  [('<sos>', 'so'),
#   ('so', 'i'),
#   ('i', 'just'),
#   ('just', 'want'),
#   ('want', 'to'),
#   ('to', 'go'),
#   ('go', 'some'),
#   ('some', 'place'),
#   ('place', 'quick'),
#   ('quick', 'for'),
#   ('for', 'lunch'),
#   ('lunch', 'get'),
#   ('get', 'a'),
#   ('a', 'sandwich'),
#   ('sandwich', 'bring'),
#   ('bring', 'it'),
#   ('it', 'back'),
#   ('back', 'to'),
#   ('to', 'my'),
#   ('my', 'desk'),
#   ('desk', '</sos>')],
#  [('<sos>', 'lunch'),
#   ('lunch', 'today'),
#   ('today', 'would'),
#   ('would', 'be'),
#   ('be', 'just'),
#   ('just', 'fine'),
#   ('fine', '</sos>')],
#  [('<sos>', 'im'),
#   ('im', 'on'),
#   ('on', 'foot'),
#   ('foot', 'so'),
#   ('so', 'it'),
#   ('it', 'better'),
#   ('better', 'be'),
#   ('be', 'close'),
#   ('close', '</sos>')],
#  [('<sos>', 'laughter'),
#   ('laughter', 'so'),
#   ('so', 'howbout'),
#   ('howbout', 'a'),
#   ('a', 'cheap'),
#   ('cheap', 'greek'),
#   ('greek', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'about'),
#   ('about', 'that'),
#   ('that', 'sleazi'),
#   ('sleazi', 'souvlaki'),
#   ('souvlaki', 'place'),
#   ('place', 'on'),
#   ('on', 'shattuck'),
#   ('shattuck', 'that'),
#   ('that', 'nobodi'),
#   ('nobodi', 'ever'),
#   ('ever', 'goe'),
#   ('goe', 'into'),
#   ('into', '</sos>')],
#  [('<sos>', 'uh'),
#   ('uh', 'i'),
#   ('i', 'wish'),
#   ('wish', 'to'),
#   ('to', 'have'),
#   ('have', 'some'),
#   ('some', 'uh'),
#   ('uh', 'fish'),
#   ('fish', 'and'),
#   ('and', 'chip'),
#   ('chip', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'have'),
#   ('have', 'fish'),
#   ('fish', 'and'),
#   ('and', 'chip'),
#   ('chip', '</sos>')],
#  [('<sos>', 'fish'), ('fish', 'and'), ('and', 'chip'), ('chip', '</sos>')],
#  [('<sos>', 'american'), ('american', 'food'), ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wish'),
#   ('wish', 'to'),
#   ('to', 'eat'),
#   ('eat', 'american'),
#   ('american', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wish'),
#   ('wish', 'to'),
#   ('to', 'eat'),
#   ('eat', 'american'),
#   ('american', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'sunday'), ('sunday', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wish'),
#   ('wish', 'to'),
#   ('to', 'eat'),
#   ('eat', 'brunch'),
#   ('brunch', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'uh'),
#   ('uh', 'drink'),
#   ('drink', 'a'),
#   ('a', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'drink'),
#   ('drink', 'a'),
#   ('a', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'drink'),
#   ('drink', 'a'),
#   ('a', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'have'),
#   ('have', 'a'),
#   ('a', 'cup'),
#   ('cup', 'of'),
#   ('of', 'coffe'),
#   ('coffe', '</sos>')],
#  [('<sos>', 'go'), ('go', 'for'), ('for', 'coffe'), ('coffe', '</sos>')],
#  [('<sos>', 'go'), ('go', 'for'), ('for', 'cafe'), ('cafe', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'go'),
#   ('go', 'to'),
#   ('to', 'a'),
#   ('a', 'unintellig'),
#   ('unintellig', '</sos>')],
#  [('<sos>', 'which'),
#   ('which', 'one'),
#   ('one', 'is'),
#   ('is', 'the'),
#   ('the', 'closest'),
#   ('closest', 'to'),
#   ('to', 'ickse'),
#   ('ickse', '</sos>')],
#  [('<sos>', 'which'),
#   ('which', 'one'),
#   ('one', 'is'),
#   ('is', 'the'),
#   ('the', 'closest'),
#   ('closest', 'to'),
#   ('to', 'icsi'),
#   ('icsi', '</sos>')],
#  [('<sos>', 'which'),
#   ('which', 'one'),
#   ('one', 'is'),
#   ('is', 'the'),
#   ('the', 'cheapest'),
#   ('cheapest', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'uh'),
#   ('uh', 'some'),
#   ('some', 'fruit'),
#   ('fruit', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'wish'),
#   ('wish', 'to'),
#   ('to', 'have'),
#   ('have', 'a'),
#   ('a', 'plate'),
#   ('plate', 'of'),
#   ('of', 'spaghetti'),
#   ('spaghetti', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'have'),
#   ('have', 'a'),
#   ('a', 'plate'),
#   ('plate', 'of'),
#   ('of', 'spaghetti'),
#   ('spaghetti', '</sos>')],
#  [('<sos>', 'do'),
#   ('do', 'you'),
#   ('you', 'know'),
#   ('know', 'where'),
#   ('where', 'i'),
#   ('i', 'can'),
#   ('can', 'eat'),
#   ('eat', 'spaghetti'),
#   ('spaghetti', '</sos>')],
#  [('<sos>', 'do'),
#   ('do', 'you'),
#   ('you', 'know'),
#   ('know', 'where'),
#   ('where', 'i'),
#   ('i', 'can'),
#   ('can', 'find'),
#   ('find', 'uh'),
#   ('uh', 'an'),
#   ('an', 'italian'),
#   ('italian', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'do'),
#   ('do', 'you'),
#   ('you', 'know'),
#   ('know', 'cough'),
#   ('cough', 'whe'),
#   ('whe', 'uh'),
#   ('uh', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'it'),
#   ('it', 'italian'),
#   ('italian', 'food'),
#   ('food', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'spend'),
#   ('spend', 'a'),
#   ('a', 'lot'),
#   ('lot', 'of'),
#   ('of', 'money'),
#   ('money', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'an'),
#   ('an', 'expens'),
#   ('expens', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'an'),
#   ('an', 'expens'),
#   ('expens', 'restaur'),
#   ('restaur', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'uh'),
#   ('uh', 'eat'),
#   ('eat', 'a'),
#   ('a', 'taco'),
#   ('taco', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'have'),
#   ('have', 'some'),
#   ('some', 'taco'),
#   ('taco', '</sos>')],
#  [('<sos>', 'where'),
#   ('where', 'can'),
#   ('can', 'i'),
#   ('i', 'eat'),
#   ('eat', 'some'),
#   ('some', 'taco'),
#   ('taco', '</sos>')],
#  [('<sos>', 'i'),
#   ('i', 'want'),
#   ('want', 'to'),
#   ('to', 'eat'),
#   ('eat', 'mexican'),
#   ('mexican', 'food'),
#   ('food', '</sos>')],
#  ...]

# %%
len(bi)
# Out:
# 8566

# %%
print(bi[1]+bi[1])
# Out:
# [('<sos>', 'i'), ('i', 'like'), ('like', 'to'), ('to', 'eat'), ('eat', 'uh'), ('uh', 'i'), ('i', 'like'), ('like', 'to'), ('to', 'eat'), ('eat', 'at'), ('at', 'lunch'), ('lunch', 'time'), ('time', 'so'), ('so', 'that'), ('that', 'would'), ('would', 'be'), ('be', 'eleven'), ('eleven', 'am'), ('am', 'to'), ('to', 'one'), ('one', 'pm'), ('pm', '</sos>'), ('<sos>', 'i'), ('i', 'like'), ('like', 'to'), ('to', 'eat'), ('eat', 'uh'), ('uh', 'i'), ('i', 'like'), ('like', 'to'), ('to', 'eat'), ('eat', 'at'), ('at', 'lunch'), ('lunch', 'time'), ('time', 'so'), ('so', 'that'), ('that', 'would'), ('would', 'be'), ('be', 'eleven'), ('eleven', 'am'), ('am', 'to'), ('to', 'one'), ('one', 'pm'), ('pm', '</sos>')]

# %%
from functools import reduce

# %%
def combine(a,b):
    return a+b

# %%
data1= reduce(combine,bi)

# %%
df= pd.DataFrame(data1,columns=['w1','w2'])
df.head()
# Out:
#       w1    w2
# 0  <sos>  okay
# 1   okay   let
# 2    let   see
# 3    see     i
# 4      i  want

# %% [markdown]
# ### PREDICTIONS:

# %%
#given 1st word is <sos> what is next word
df[df['w1']=='<sos>'].head()
# Out:
#        w1    w2
# 0   <sos>  okay
# 20  <sos>     i
# 42  <sos>     i
# 53  <sos>  tell
# 68  <sos>     i

# %%
#preparing data by adding count column
df['count']=df['w2']
df.head(3)
# Out:
#       w1    w2 count
# 0  <sos>  okay  okay
# 1   okay   let   let
# 2    let   see   see

# %%
model_next = df.groupby(by=['w1','w2']).count()
model_next.reset_index(inplace=True)
model_next
# Out:
#              w1            w2  count
# 0         <sos>             a     29
# 1         <sos>         about     49
# 2         <sos>        actual     14
# 3         <sos>       addison      1
# 4         <sos>       african      2
# 5         <sos>         after      2
# 6         <sos>         again      2
# 7         <sos>            ah      2
# 8         <sos>       alacart      1
# 9         <sos>           all      6
# 10        <sos>          also      1
# 11        <sos>      american     15
# 12        <sos>            an      4
# 13        <sos>           and     44
# 14        <sos>           ani    111
# 15        <sos>         anyth      3
# 16        <sos>        anytim      1
# 17        <sos>       anywher     16
# 18        <sos>           are     70
# 19        <sos>          area      2
# 20        <sos>         arent      2
# 21        <sos>  arinellpizza      2
# 22        <sos>        around      7
# 23        <sos>            as      9
# 24        <sos>         asian      2
# 25        <sos>            at     14
# 26        <sos>    aucoquelet      7
# 27        <sos>    australian      1
# 28        <sos>     aycaramba      3
# 29        <sos>          back      2
# ...         ...           ...    ...
# 10084      youd            be      2
# 10085      your          data      1
# 10086      your       databas      3
# 10087      your          dine      2
# 10088      your       display      1
# 10089      your       favorit      2
# 10090      your         first      1
# 10091      your            go      1
# 10092      your          list      8
# 10093      your          name      1
# 10094      your         place      1
# 10095      your      question      1
# 10096      your          quit      1
# 10097      your        realli      1
# 10098      your            so      1
# 10099      your        system      1
# 10100      your         total      1
# 10101      your         wrong      1
# 10102  yourself        </sos>      1
# 10103      youv          been      1
# 10104      youv           got      1
# 10105      yuck            uh      1
# 10106     yuppi    california      1
# 10107   zachari        </sos>      1
# 10108   zachari           ani      1
# 10109   zachari       chicago      2
# 10110   zachari         close      1
# 10111   zachari            is      1
# 10112   zachari         pizza      3
# 10113  zucchini           fri      2
#
# [10114 rows x 3 columns]

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
given = '<sos>'  # given word
model = model_next[model_next['w1']== given]  # filtered list
den= model['count'].sum()  # counting given word in the corpus
model['probability']= model['count']/den    # calculating the prob of each word
# arrange in decesing order
m1= model.sort_values(by='probability',ascending=False).head()
m1.set_index('w1',inplace=True)
print(m1[['w2','probability']])
# Out:
#           w2  probability
# w1
# <sos>      i     0.226710
# <sos>     id     0.061873
# <sos>  start     0.036423
# <sos>   tell     0.035022
# <sos>   what     0.028251

# %%
# model_next: consists of all information
def nextword(given):
    #given = '<sos>'  # given word
    model = model_next[model_next['w1']== given]  # filtered list
    den= model['count'].sum()  # counting given word in the corpus
    model['probability']= model['count']/den    # calculating the prob of each word
# arrange in decesing order
    m1= model.sort_values(by='probability',ascending=False).head()
    m1.set_index('w1',inplace=True)
    return m1[['w2','probability']]

# %% [markdown]
# ### UI

# %%
while True:
    given = input('USER: ')
    if given == 'quit':
        break
    else:
        table = nextword(given)
        print(table)
# Out:
# USER:
# Empty DataFrame
# Columns: [w2, probability]
# Index: []
# USER:
# Empty DataFrame
# Columns: [w2, probability]
# Index: []
# USER:
# Empty DataFrame
# Columns: [w2, probability]
# Index: []
# USER: hi
#      w2  probability
# w1
# hi    i     0.400000
# hi   im     0.342857
# hi   id     0.114286
# hi  can     0.057143
# hi   uh     0.057143
# USER: hello
#                w2  probability
# w1
# hello      </sos>     0.321429
# hello           i     0.285714
# hello        berp     0.071429
# hello          im     0.071429
# hello  loudbreath     0.071429
# USER: what
#          w2  probability
# w1
# what  about     0.246201
# what     is     0.130699
# what     do     0.097264
# what   kind     0.066869
# what    are     0.045593
# USER: how
#         w2  probability
# w1
# how  about     0.598174
# how   much     0.127854
# how    far     0.095890
# how   mani     0.041096
# how    can     0.022831
# USER: if
#       w2  probability
# w1
# if     i     0.375000
# if    it     0.166667
# if   you     0.104167
# if   the     0.062500
# if  they     0.062500
# USER: i
#        w2  probability
# w1
# i    want     0.329466
# i   would     0.260900
# i    dont     0.082278
# i     wan     0.040788
# i    have     0.037975
# USER: quit
